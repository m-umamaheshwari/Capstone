# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load and Understand the Data

# %%
data_desc = pd.read_excel('Capstone-final-addedrows.xlsx',sheet_name='Description')
data_desc.head()
# Out:
#                                  Unnamed: 0     Unnamed: 1 Unnamed: 2
# 0                       Feature Description            NaN        NaN
# 1                                       NaN  Before Corona    Present
# 2                                   Generic            NaN        NaN
# 3  A unique identifier for every individual             ID         ID
# 4                         What is your age?            Age        Age

# %%
data_desc.shape
# Out:
# (56, 3)

# %%
data_desc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 3 columns):
# Unnamed: 0    51 non-null object
# Unnamed: 1    46 non-null object
# Unnamed: 2    46 non-null object
# dtypes: object(3)
# memory usage: 1.4+ KB

# %% [markdown]
# ### DATA CONTAINING THE INFO BEFORE THE PANDEMIC

# %%
data_before = pd.read_excel('Capstone-final-addedrows.xlsx',sheet_name='Before Corona')
data_before.head()
# Out:
#    ID    Age                                    Income  \
# 0   1    55+                      3 - 5 lakh per annum
# 1   2    55+                        20+ lakh per annum
# 2   3  20-25                     5 - 10 lakh per annum
# 3   4  40-55                    Under 3 lakh per annum
# 4   5  20-25  I don't earn right now (maybe in future)
#
#                                Emp_stat_Before  Gender Marital_status  \
# 0  Unemployed (not currently looking for work)    Male            Yes
# 1                                      Student    Male            Yes
# 2                      Private Sector Employee    Male             No
# 3                                Self-Employed    Male            Yes
# 4                                      Student  Female             No
#
#          Loc Notice_things_Before  All_angles_Before Sincere_prod_Before  ...  \
# 0  Telangana       Strongly agree              Agree             Neutral  ...
# ...

# %%
data_before.shape
# Out:
# (551, 43)

# %%
data_before.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551 entries, 0 to 550
# Data columns (total 43 columns):
# ID                             551 non-null int64
# Age                            549 non-null object
# Income                         532 non-null object
# Emp_stat_Before                512 non-null object
# Gender                         548 non-null object
# Marital_status                 545 non-null object
# Loc                            544 non-null object
# Notice_things_Before           541 non-null object
# All_angles_Before              541 non-null object
# Sincere_prod_Before            541 non-null object
# Lonely_Before                  541 non-null object
# Worry_health_Before            536 non-null object
# Charity_Before                 541 non-null object
# New_env_Before                 540 non-null object
# Meeting_ppl_Before             539 non-null object
# Hob_interests_Before           541 non-null object
# ...

# %%
data_before.describe(include='O')
# Out:
#           Age                                    Income  \
# count     549                                       532
# unique      6                                         6
# top     20-25  I don't earn right now (maybe in future)
# freq      263                                       145
#
#                 Emp_stat_Before Gender Marital_status        Loc  \
# count                       512    548            545        544
# unique                        6      3              2         58
# top     Private Sector Employee   Male             No  Telangana
# freq                        275    282            331        284
#
#        Notice_things_Before All_angles_Before Sincere_prod_Before  \
# count                   541               541                 541
# unique                    5                 5                   5
# top                   Agree             Agree               Agree
# freq                    221               249                 237
#
# ...

# %%
cols = data_before.columns

# %%
# replace null values with No data
for i in range(1,len(cols)):
    if(i!=41):
        data_before[cols[i]].replace(np.nan,'No Data',inplace=True)
    else:
        continue

# %%
data_before.isnull().sum()
# Out:
# ID                             0
# Age                            0
# Income                         0
# Emp_stat_Before                0
# Gender                         0
# Marital_status                 0
# Loc                            0
# Notice_things_Before           0
# All_angles_Before              0
# Sincere_prod_Before            0
# Lonely_Before                  0
# Worry_health_Before            0
# Charity_Before                 0
# New_env_Before                 0
# Meeting_ppl_Before             0
# Hob_interests_Before           0
# Surveys_Before                 0
# Spent_onli_Before              0
# WFH_office_Before              0
# Enthu_Before                   0
# Smoking_hab_Before             0
# Drinking_hab_Before            0
# Sleeping_hab_Before            0
# Healthy_Lifestyle_Before       0
# Medi_pref_Before               0
# Pol_interest_Before            0
# Internet_interest_Before       0
# Economy_Manag_intrst_Before    0
# ...

# %% [markdown]
# ### DATA CONTAINING THE INFO OF PRESENT SITUATION

# %%
data_present = pd.read_excel('Capstone-final-addedrows.xlsx',sheet_name='Present')
data_present.head()
# Out:
#    ID    Age                                    Income  \
# 0   1    55+                      3 - 5 lakh per annum
# 1   2    55+                        20+ lakh per annum
# 2   3  20-25                     5 - 10 lakh per annum
# 3   4  40-55                    Under 3 lakh per annum
# 4   5  20-25  I don't earn right now (maybe in future)
#
#                               Emp_stat_Present  Gender Marital_status  \
# 0  Unemployed (not currently looking for work)    Male            Yes
# 1                                      Student    Male            Yes
# 2                                          NaN    Male             No
# 3                                Self-Employed    Male            Yes
# 4                                      Student  Female             No
#
#          Loc Notice_things_Present All_angles_Present Sincere_prod_Present  \
# 0  Telangana        Strongly agree     Strongly Agree       Strongly agree
# ...

# %%
data_present.describe(include='O')
# Out:
#           Age                                    Income  \
# count     549                                       532
# unique      6                                         6
# top     20-25  I don't earn right now (maybe in future)
# freq      263                                       145
#
#                Emp_stat_Present Gender Marital_status        Loc  \
# count                       499    548            545        544
# unique                        6      3              2         58
# top     Private Sector Employee   Male             No  Telangana
# freq                        238    282            331        284
#
#        Notice_things_Present All_angles_Present Sincere_prod_Present  \
# count                    541                537                  545
# unique                     5                  5                    5
# top                    Agree              Agree                Agree
# freq                     232                256                  243
#
# ...

# %%
data_present.shape,data_before.shape
# Out:
# ((551, 46), (551, 43))

# %% [markdown]
# ### 1.ANALYSING THE PERSONALITY OF PEOPLE WHO ARE LONELY, CONSIDERING VARIOUS ASPECTS LIKE AGE,INCOME,GENDER,MARITAL STATUS

# %% [markdown]
# ### Before the pandemic

# %%
# people who are lonely based on their MARITAL STATUS (overall analysis)
plt.figure(figsize=(15,8))
sns.countplot(data_before['Lonely_Before'],hue='Marital_status',data=data_before)

# %%
mar_grp = data_before[(data_before['Lonely_Before']=='Agree') | 
            (data_before['Lonely_Before']=='Strongly Agree')].groupby('Marital_status')

# %%
mar_grp.groups
# Out:
# {'No': Int64Index([  6,  10,  18,  22,  43,  47,  59,  67,  69,  72,  73,  76,  80,
#               81,  88,  91,  97, 101, 150, 154, 156, 163, 164, 173, 184, 189,
#              216, 230, 242, 247, 253, 257, 261, 263, 274, 275, 279, 281, 305,
#              308, 309, 315, 338, 339, 350, 354, 357, 358, 359, 361, 362, 367,
#              385, 391, 412, 423, 452, 457, 472, 478, 485, 490, 491, 492, 493,
#              501, 529, 530],
#             dtype='int64'),
#  'Yes': Int64Index([  0,  40,  82, 110, 127, 240, 264, 299, 333, 345, 363, 371, 392,
#              409, 414, 415, 453, 527],
#             dtype='int64')}

# %%
mar_grp.count()
# Out:
#                 ID  Age  Income  Emp_stat_Before  Gender  Loc  \
# Marital_status
# No              68   68      68               68      68   68
# Yes             18   18      18               18      18   18
#
#                 Notice_things_Before  All_angles_Before  Sincere_prod_Before  \
# Marital_status
# No                                68                 68                   68
# Yes                               18                 18                   18
#
#                 Lonely_Before  ...  Mode_of_transport_Before  \
# Marital_status                 ...
# No                         68  ...                        68
# Yes                        18  ...                        18
#
#                 Basic_medications_Before  Digital_content_Before  \
# Marital_status
# No                                    68                      68
# Yes                                   18                      18
#
#                 Active_Investor_Before  Edu_instit_fee_Before  \
# ...

# %%
mar_grp_No = mar_grp.get_group('No')
mar_grp_Yes = mar_grp.get_group('Yes')

# %%
total_no_of_lonely_ppl = len(mar_grp_No)+len(mar_grp_Yes)
total_no_of_lonely_ppl
# Out:
# 86

# %%
married_lonely_percent = (len(mar_grp_Yes)/total_no_of_lonely_ppl)*100
Unmarried_lonely_percent = (len(mar_grp_No)/total_no_of_lonely_ppl)*100

# %%
print("Percentage of non-married people feeling lonely out of all the people feeling lonely : ",Unmarried_lonely_percent)
print("Percentage of married people feeling lonely out of all the people feeling lonely : ",married_lonely_percent)
# Out:
# Percentage of non-married people feeling lonely out of all the people feeling lonely :  79.06976744186046
# Percentage of married people feeling lonely out of all the people feeling lonely :  20.930232558139537

# %%
percent_values_lonely = [Unmarried_lonely_percent,married_lonely_percent]
labels_marriage = ['Unmarried and lonely','Married and lonely']

# %%
fig,axes=plt.subplots(1,2,figsize=(15,15))
axes[0].pie(data_before['Marital_status'].value_counts().values,labels=data_before['Marital_status'].value_counts().index,explode=[0.03,0.05,0.2],autopct='%1.2f%%')
axes[1].pie(percent_values_lonely,labels=labels_marriage,explode=[0.1,0],autopct='%1.2ff%%')

axes[0].set_title('count of married and Unmarried people')
axes[1].set_title('count of married and unmarried people who are lonely before the pandemic')

plt.show()

# %%
## personality traits of married people who are lonely (specific analysis)

# %%
personality_trait_cols = data_before.columns[0:24]

# %%
married_lonely_personality_traits = data_before[(data_before['Marital_status']=='Yes') & 
            ((data_before['Lonely_Before']=='Agree') | (data_before['Lonely_Before']=='Strongly Agree'))][personality_trait_cols]

# %%
personality_trait_cols
# Out:
# Index(['ID', 'Age', 'Income', 'Emp_stat_Before', 'Gender', 'Marital_status',
#        'Loc', 'Notice_things_Before', 'All_angles_Before',
#        'Sincere_prod_Before', 'Lonely_Before', 'Worry_health_Before',
#        'Charity_Before', 'New_env_Before', 'Meeting_ppl_Before',
#        'Hob_interests_Before', 'Surveys_Before', 'Spent_onli_Before',
#        'WFH_office_Before', 'Enthu_Before', 'Smoking_hab_Before',
#        'Drinking_hab_Before', 'Sleeping_hab_Before',
#        'Healthy_Lifestyle_Before'],
#       dtype='object')

# %%
married_lonely_personality_traits
# Out:
#       ID    Age                                    Income  \
# 0      1    55+                      3 - 5 lakh per annum
# 40    41  30-35                      3 - 5 lakh per annum
# 82    83  20-25                     5 - 10 lakh per annum
# 110  111  40-55                     5 - 10 lakh per annum
# 127  128    55+                     5 - 10 lakh per annum
# 240  241  40-55                        20+ lakh per annum
# 264  265  35-40  I don't earn right now (maybe in future)
# 299  300  20-25  I don't earn right now (maybe in future)
# 333  334  40-55                     5 - 10 lakh per annum
# 345  346  40-55                    10 - 20 lakh per annum
# 363  364  30-35                    Under 3 lakh per annum
# 371  372  40-55                      3 - 5 lakh per annum
# 392  393    55+  I don't earn right now (maybe in future)
# 409  410    55+                    10 - 20 lakh per annum
# 414  415    55+                        20+ lakh per annum
# ...

# %%
married_lonely_personality_traits.describe(include='O')
# Out:
#         Age              Income          Emp_stat_Before Gender  \
# count    18                  18                       18     18
# unique    5                   6                        5      3
# top     55+  20+ lakh per annum  Private Sector Employee   Male
# freq      7                   4                        8      9
#
#        Marital_status        Loc Notice_things_Before All_angles_Before  \
# count              18         18                   18                18
# unique              1          8                    4                 4
# top               Yes  Telangana              Neutral             Agree
# freq               18          9                    9                10
#
#        Sincere_prod_Before Lonely_Before  ... Meeting_ppl_Before  \
# count                   18            18  ...                 18
# unique                   5             2  ...                  6
# top         Strongly agree         Agree  ...              Agree
# ...

# %%
#dominant personality of people who are married and lonely - can be observed as people who are family oriented
# who are the ones who are misunderstood to be happy and content
married_lonely_personality_traits.describe(include='O').loc['top',:]
# Out:
# Age                                                    55+
# Income                                  20+ lakh per annum
# Emp_stat_Before                    Private Sector Employee
# Gender                                                Male
# Marital_status                                         Yes
# Loc                                              Telangana
# Notice_things_Before                               Neutral
# All_angles_Before                                    Agree
# Sincere_prod_Before                         Strongly agree
# Lonely_Before                                        Agree
# Worry_health_Before                                  Agree
# Charity_Before                                    Disagree
# New_env_Before                                       Agree
# Meeting_ppl_Before                                   Agree
# Hob_interests_Before                               Neutral
# Surveys_Before                                     Neutral
# ...

# %%
len(data_before[data_before['Age']=='55+'])
# Out:
# 29

# %%
(data_before['Age'].value_counts()/data_before['Age'].value_counts().sum())*100
# Out:
# 20-25      47.731397
# 25-30      15.607985
# 40-55      14.882033
# 30-35      10.344828
# 35-40       5.807623
# 55+         5.263158
# No Data     0.362976
# Name: Age, dtype: float64

# %%
## personality traits of unmarried people who are lonely (specific analysis)
unmarried_lonely_personality_traits = data_before[(data_before['Marital_status']=='No') & 
            ((data_before['Lonely_Before']=='Agree') | (data_before['Lonely_Before']=='Strongly Agree'))][personality_trait_cols]

# %%
unmarried_lonely_personality_traits
# Out:
#       ID    Age                                    Income  \
# 6      7  20-25                    10 - 20 lakh per annum
# 10    11  20-25  I don't earn right now (maybe in future)
# 18    19  20-25                     5 - 10 lakh per annum
# 22    23  25-30                      3 - 5 lakh per annum
# 43    44  20-25                     5 - 10 lakh per annum
# ..   ...    ...                                       ...
# 492  493  20-25  I don't earn right now (maybe in future)
# 493  494  25-30  I don't earn right now (maybe in future)
# 501  502  20-25                     5 - 10 lakh per annum
# 529  530  40-55                    10 - 20 lakh per annum
# 530  531  30-35                      3 - 5 lakh per annum
#
#              Emp_stat_Before  Gender Marital_status             Loc  \
# 6    Private Sector Employee    Male             No       Telangana
# 10                   Student    Male             No       Telangana
# ...

# %%
unmarried_lonely_personality_traits.describe(include='O')
# Out:
#           Age                                    Income  \
# count      68                                        68
# unique      4                                         7
# top     20-25  I don't earn right now (maybe in future)
# freq       46                                        23
#
#                 Emp_stat_Before Gender Marital_status        Loc  \
# count                        68     68             68         68
# unique                        6      3              1         20
# top     Private Sector Employee   Male             No  Telangana
# freq                         37     38             68         42
#
#        Notice_things_Before All_angles_Before Sincere_prod_Before  \
# count                    68                68                  68
# unique                    5                 5                   5
# top                   Agree             Agree               Agree
# freq                     37                26                  30
#
# ...

# %%
# dominant personality of people who are unmarried and lonely
# unemployed youth who doesnot follow a proper health routine
# its very important to have a very healthy routine (physical and mental)
# They can think of having a direction in life, start being responsible
#can ead to they being assets for the country and help boost the economy, and 
#also can lead to less disputes in the family leading to healthy family relations where everyone is mentally sound.

unmarried_lonely_personality_traits.describe(include='O').loc['top',:]
# Out:
# Age                                                            20-25
# Income                      I don't earn right now (maybe in future)
# Emp_stat_Before                              Private Sector Employee
# Gender                                                          Male
# Marital_status                                                    No
# Loc                                                        Telangana
# Notice_things_Before                                           Agree
# All_angles_Before                                              Agree
# Sincere_prod_Before                                            Agree
# Lonely_Before                                                  Agree
# Worry_health_Before                                          Neutral
# Charity_Before                                                 Agree
# New_env_Before                                                 Agree
# Meeting_ppl_Before                                             Agree
# ...

# %%
## people who are lonely based on their GENDER (overall analysis)
plt.figure(figsize=(15,8))
sns.countplot(data_before['Lonely_Before'],hue='Gender',data=data_before)

# %%
gender_grp = data_before[(data_before['Lonely_Before']=='Agree') | 
            (data_before['Lonely_Before']=='Strongly Agree')].groupby('Gender')

# %%
gender_grp.groups
# Out:
# {'Female': Int64Index([ 43,  47,  59,  67,  73,  82,  88,  97, 101, 110, 150, 173, 184,
#              216, 230, 253, 261, 264, 274, 275, 281, 299, 305, 315, 333, 358,
#              359, 362, 363, 367, 391, 392, 423, 490, 491, 529],
#             dtype='int64'),
#  'Male': Int64Index([  0,   6,  10,  18,  22,  40,  69,  72,  76,  80,  81,  91, 127,
#              154, 156, 163, 164, 189, 240, 242, 247, 257, 263, 279, 309, 338,
#              339, 345, 350, 354, 357, 361, 371, 385, 409, 412, 452, 453, 457,
#              472, 478, 485, 492, 493, 501, 527, 530],
#             dtype='int64'),
#  'Prefer not to say': Int64Index([308, 414, 415], dtype='int64')}

# %%
gender_grp.count()
# Out:
#                    ID  Age  Income  Emp_stat_Before  Marital_status  Loc  \
# Gender
# Female             36   36      36               36              36   36
# Male               47   47      47               47              47   47
# Prefer not to say   3    3       3                3               3    3
#
#                    Notice_things_Before  All_angles_Before  \
# Gender
# Female                               36                 36
# Male                                 47                 47
# Prefer not to say                     3                  3
#
#                    Sincere_prod_Before  Lonely_Before  ...  \
# Gender                                                 ...
# Female                              36             36  ...
# Male                                47             47  ...
# Prefer not to say                    3              3  ...
#
#                    Mode_of_transport_Before  Basic_medications_Before  \
# Gender
# ...

# %%
gender_grp_Female = gender_grp.get_group('Female')
gender_grp_Male = gender_grp.get_group('Male')
gender_grp_Prefer_not_to_say = gender_grp.get_group('Prefer not to say')

# %%
total_no_of_lonely_ppl_gen = len(gender_grp_Female)+len(gender_grp_Male)+len(gender_grp_Prefer_not_to_say)
total_no_of_lonely_ppl_gen
# Out:
# 86

# %%
male_lonely_percent = (len(gender_grp_Male)/total_no_of_lonely_ppl_gen)*100
female_lonely_percent = (len(gender_grp_Female)/total_no_of_lonely_ppl_gen)*100
others_lonely_percent = (len(gender_grp_Prefer_not_to_say)/total_no_of_lonely_ppl_gen)*100

# %%
percent_gender_lonely = [male_lonely_percent,female_lonely_percent,others_lonely_percent]
labels_gender= ['lonely males','lonely females','others(prefer not to say) lonely']

# %%
fig1,axes1=plt.subplots(1,2,figsize=(15,15))
axes1[0].pie(data_before['Gender'].value_counts().values,
        labels=data_before['Gender'].value_counts().index,explode=[0.05,0.08,0.3,0.1],autopct='%1.2f%%')
axes1[1].pie(percent_gender_lonely,labels=labels_gender,explode=[0.1,0.05,0],autopct='%1.2ff%%')

axes1[0].set_title('count of males and females')
axes1[1].set_title('count of genders who are lonely before the pandemic')

plt.show()

# %%
data_before[(data_before['Gender']=='Prefer not to say') & 
            (data_before['Marital_status']=='Yes') &
           ((data_before['Lonely_Before']=='Agree')|
            (data_before['Lonely_Before']=='Strongly Agree'))][['ID','Age','Gender','Marital_status','Lonely_Before']]
# Out:
#       ID  Age             Gender Marital_status   Lonely_Before
# 414  415  55+  Prefer not to say            Yes           Agree
# 415  416  55+  Prefer not to say            Yes  Strongly Agree

# %%
data_before[(data_before['Gender']=='Prefer not to say') & 
            (data_before['Marital_status']=='No') &
           ((data_before['Lonely_Before']=='Agree')|
            (data_before['Lonely_Before']=='Strongly Agree'))][['ID','Age','Gender','Marital_status','Lonely_Before']]
# Out:
#       ID    Age             Gender Marital_status Lonely_Before
# 308  309  20-25  Prefer not to say             No         Agree

# %%
'''
compared to the proportion of people who didnot prefer to disclose their gender, the percent of people in this
category who marked that they are feeling lonely is significantly high, this can be because of two reasons :-

1.people doesnt want to disclose their gender, and stay anonymous with their answers
2.Can also be that , these people doesnt belong to any of the genders given, they feeling lonely can bring in
many societal factors.
3.Surprisingly , it has been observed both with respect to marital status and gender the dominant
age group that is feeling lonely is 55+ married people(irrespective of the effect of the pandemic),

considering the number of people who filled the form who are of 55+ age(29) , the proportion feeling lonely are 
significantly high. 

'''

# %%
# people who are lonely and the influence of income status
plt.figure(figsize=(15,8))
sns.countplot(data_before['Lonely_Before'],hue='Income',data=data_before)

# %%
inc_grp = data_before[(data_before['Lonely_Before']=='Agree') | 
            (data_before['Lonely_Before']=='Strongly Agree')].groupby('Income')

# %%
inc_grp.groups
# Out:
# {'10 - 20 lakh per annum': Int64Index([6, 76, 81, 345, 409, 452, 527, 529], dtype='int64'),
#  '20+ lakh per annum': Int64Index([47, 240, 261, 367, 414, 415, 453], dtype='int64'),
#  '3 - 5 lakh per annum': Int64Index([  0,  22,  40,  80, 150, 156, 163, 173, 216, 230, 242, 308, 315,
#              339, 350, 357, 359, 371, 457, 472, 478, 490, 491, 530],
#             dtype='int64'),
#  '5 - 10 lakh per annum': Int64Index([18, 43, 82, 110, 127, 257, 263, 333, 338, 361, 391, 412, 501], dtype='int64'),
#  "I don't earn right now (maybe in future)": Int64Index([ 10,  59,  67,  72,  73,  88,  91,  97, 101, 184, 247, 253, 264,
#              274, 275, 299, 305, 309, 354, 358, 362, 392, 423, 485, 492, 493],
#             dtype='int64'),
#  'No Data': Int64Index([154], dtype='int64'),
#  'Under 3 lakh per annum': Int64Index([69, 164, 189, 279, 281, 363, 385], dtype='int64')}

# %%
inc_grp_10to20 = inc_grp.get_group('10 - 20 lakh per annum')
inc_grp_20plus = inc_grp.get_group('20+ lakh per annum')
inc_grp_3to5 = inc_grp.get_group('3 - 5 lakh per annum')
inc_grp_5to10 = inc_grp.get_group('5 - 10 lakh per annum')
inc_grp_no_earnings_currently = inc_grp.get_group("I don't earn right now (maybe in future)")
inc_grp_nodata = inc_grp.get_group('No Data')
inc_grp_under3 = inc_grp.get_group('Under 3 lakh per annum')

# %%
inc10to20_lonely_percent = (len(inc_grp_10to20)/total_no_of_lonely_ppl)*100
inc20plus_lonely_percent = (len(inc_grp_20plus)/total_no_of_lonely_ppl)*100
inc3to5_lonely_percent = (len(inc_grp_3to5)/total_no_of_lonely_ppl)*100
inc5to10_lonely_percent = (len(inc_grp_5to10)/total_no_of_lonely_ppl)*100
inc_noearnings_lonely_percent = (len(inc_grp_no_earnings_currently)/total_no_of_lonely_ppl)*100
incNodata_lonely_percent = (len(inc_grp_nodata)/total_no_of_lonely_ppl)*100
incUnder3_lonely_percent = (len(inc_grp_under3)/total_no_of_lonely_ppl)*100

# %%
percent_income_lonely = [inc10to20_lonely_percent,inc20plus_lonely_percent,inc3to5_lonely_percent,
                        inc5to10_lonely_percent,inc_noearnings_lonely_percent,incNodata_lonely_percent,
                        incUnder3_lonely_percent]
labels_income= ['10 - 20 lakh per annum','20+ lakh per annum','3 - 5 lakh per annum','5 - 10 lakh per annum',
               "I don't earn right now (maybe in future)",'No Data','Under 3 lakh per annum']

# %%
fig2,axes2=plt.subplots(1,2,figsize=(20,15))
axes2[0].pie(data_before['Income'].value_counts().values,
        labels=data_before['Income'].value_counts().index,explode=[0,0,0,0,0,0,0],autopct='%1.2f%%')
axes2[1].pie(percent_income_lonely,labels=labels_income,explode=[0,0,0,0,0,0,0],autopct='%1.2ff%%')

axes2[0].set_title('people belonging to different income groups')
axes2[1].set_title('people belonging to different income groups feeling lonely before the pandemic')

plt.show()

# %%
# dominant personality of people belonging to the income group 3-5 lakh per annum who are feeling lonely
data_before[(data_before['Income']=='3 - 5 lakh per annum') & 
            ((data_before['Lonely_Before']=='Agree') | 
             (data_before['Lonely_Before']=='Strongly Agree'))].describe(include='O')
# Out:
#           Age                Income          Emp_stat_Before Gender  \
# count      24                    24                       24     24
# unique      5                     1                        5      3
# top     20-25  3 - 5 lakh per annum  Private Sector Employee   Male
# freq       14                    24                       17     15
#
#        Marital_status        Loc Notice_things_Before All_angles_Before  \
# count              24         24                   24                24
# unique              2          8                    5                 4
# top                No  Telangana                Agree           Neutral
# freq               21         15                    8                 9
#
#        Sincere_prod_Before Lonely_Before  ...            Food_pref_Before  \
# count                   24            24  ...                          24
# unique                   5             2  ...                           2
# ...

# %%
income3to5_personality_traits = data_before[(data_before['Income']=='3 - 5 lakh per annum') & 
            ((data_before['Lonely_Before']=='Agree') | 
             (data_before['Lonely_Before']=='Strongly Agree'))][personality_trait_cols]

# %%
income3to5_personality_traits.describe(include='O').loc['top',:]
# Out:
# Age                                                 20-25
# Income                               3 - 5 lakh per annum
# Emp_stat_Before                   Private Sector Employee
# Gender                                               Male
# Marital_status                                         No
# Loc                                             Telangana
# Notice_things_Before                                Agree
# All_angles_Before                                 Neutral
# Sincere_prod_Before                                 Agree
# Lonely_Before                                       Agree
# Worry_health_Before                               Neutral
# Charity_Before                                   Disagree
# New_env_Before                                      Agree
# Meeting_ppl_Before                                  Agree
# Hob_interests_Before                              Neutral
# Surveys_Before                                    Neutral
# ...

# %%
'''
considering the proportions , we can say that people belonging to income group 3-5 lakh per annum are feeling more
lonely than others, other income groups contributed equally to the lonely trait.

1.These are the younger generations who just got out out of college or are in their early years of career, mainly
age groups 20-25,25-30.

2.Most of them dont hold a healthy routine where we can see they often eat food from outside and irregular sleeping
habits

3.Majority of them are not vigilant enough where they dont hold a basic medication kit if things go wrong, basically
are not taking complete rsponsibility of their mental and physical health.

4.It can also be observed that private sector employees are mostly feeling lonely or are having
this tendency as most of their time is spent infront of systems which will affect them psychologically and would 
worsen things if they dont have an active healthy lifestye that can compensate the stress caused here.

'''

# %% [markdown]
# ### During the pandemic

# %%
data_present.shape
# Out:
# (551, 46)

# %%
(data_present['Age'].value_counts()/data_present['Age'].value_counts().sum())*100
# Out:
# 20-25      47.731397
# 25-30      15.607985
# 40-55      14.882033
# 30-35      10.344828
# 35-40       5.807623
# 55+         5.263158
# No Data     0.362976
# Name: Age, dtype: float64

# %%
data_present.iloc[ids_married_lonely-1]
# Out:
#       ID    Age                                    Income  \
# 0      1    55+                      3 - 5 lakh per annum
# 40    41  30-35                      3 - 5 lakh per annum
# 82    83  20-25                     5 - 10 lakh per annum
# 110  111  40-55                     5 - 10 lakh per annum
# 127  128    55+                     5 - 10 lakh per annum
# 240  241  40-55                        20+ lakh per annum
# 264  265  35-40  I don't earn right now (maybe in future)
# 299  300  20-25  I don't earn right now (maybe in future)
# 333  334  40-55                     5 - 10 lakh per annum
# 345  346  40-55                    10 - 20 lakh per annum
# 363  364  30-35                    Under 3 lakh per annum
# 371  372  40-55                      3 - 5 lakh per annum
# 392  393    55+  I don't earn right now (maybe in future)
# 409  410    55+                    10 - 20 lakh per annum
# 414  415    55+                        20+ lakh per annum
# ...

# %%
data_present.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551 entries, 0 to 550
# Data columns (total 46 columns):
# ID                              551 non-null int64
# Age                             549 non-null object
# Income                          532 non-null object
# Emp_stat_Present                499 non-null object
# Gender                          548 non-null object
# Marital_status                  545 non-null object
# Loc                             544 non-null object
# Notice_things_Present           541 non-null object
# All_angles_Present              537 non-null object
# Sincere_prod_Present            545 non-null object
# Lonely_Present                  544 non-null object
# Worry_health_Present            542 non-null object
# Charity_Present                 540 non-null object
# New_env_Present                 544 non-null object
# Meeting_ppl_Present             540 non-null object
# Hob_interests_Present           544 non-null object
# ...

# %%
data_present.isnull().sum()
# Out:
# ID                               0
# Age                              2
# Income                          19
# Emp_stat_Present                52
# Gender                           3
# Marital_status                   6
# Loc                              7
# Notice_things_Present           10
# All_angles_Present              14
# Sincere_prod_Present             6
# Lonely_Present                   7
# Worry_health_Present             9
# Charity_Present                 11
# New_env_Present                  7
# Meeting_ppl_Present             11
# Hob_interests_Present            7
# Surveys_Present                 11
# Spent_onli_Present               4
# WFH_office_Present              10
# Ethu_Present                     8
# Income_Change                   31
# Smoking_hab_Present              8
# Drinking_hab_Present             5
# Sleeping_hab_Present             9
# Healthy_Lifestyle_Present        9
# Medi_pref_Present               83
# Pol_interest_Present             9
# ...

# %%
cols_present = data_present.columns

# %%
# replace null values with No data
for i in range(1,len(cols_present)):
    if(i!=44):
        data_present[cols_present[i]].replace(np.nan,'No Data',inplace=True)
    else:
        continue

# %%
data_present.isnull().sum()
# Out:
# ID                              0
# Age                             0
# Income                          0
# Emp_stat_Present                0
# Gender                          0
# Marital_status                  0
# Loc                             0
# Notice_things_Present           0
# All_angles_Present              0
# Sincere_prod_Present            0
# Lonely_Present                  0
# Worry_health_Present            0
# Charity_Present                 0
# New_env_Present                 0
# Meeting_ppl_Present             0
# Hob_interests_Present           0
# Surveys_Present                 0
# Spent_onli_Present              0
# WFH_office_Present              0
# Ethu_Present                    0
# Income_Change                   0
# Smoking_hab_Present             0
# Drinking_hab_Present            0
# Sleeping_hab_Present            0
# Healthy_Lifestyle_Present       0
# Medi_pref_Present               0
# Pol_interest_Present            0
# ...

# %%
plt.figure(figsize=(27,5))
pd.crosstab(data_present['Marital_status'],data_present['Lonely_Present']).plot(kind='barh',stacked=True)
plt.show()

# %%
pd.crosstab(data_present['Marital_status'],data_present['Lonely_Present'])
# Out:
# Lonely_Present  Agree  Disagree  Neutral  No Data  Strongly Agree  \
# Marital_status
# No                 75        77       62        5              54
# No Data             1         2        0        1               0
# Yes                45        55       37        1              13
#
# Lonely_Present  Strongly disagree
# Marital_status
# No                             58
# No Data                         2
# Yes                            63

# %%
len(data_before[(data_before['Lonely_Before']=='Agree') | (data_before['Lonely_Before']=='Strongly Agree')])
# Out:
# 86

# %%
len(data_present[(data_present['Lonely_Present']=='Agree') | (data_present['Lonely_Present']=='Strongly Agree')])
# Out:
# 188

# %%
# overall analysis of people feeling lonely currently
plt.figure(figsize=(20,7))
sns.countplot(data_present['Lonely_Present'],hue='Meeting_ppl_Present',data=data_present)
plt.show()

# %%
plt.figure(figsize=(22,7))
sns.countplot(data_present['Spent_onli_Present'],hue='Lonely_Present',data=data_present)
plt.show()

# %%
data_present[(data_present['Lonely_Present']=='Agree') & 
             (data_present['Spent_onli_Present']=='Less than ')]['Emp_stat_Present'].value_counts()
# Out:
# Series([], Name: Emp_stat_Present, dtype: int64)

# %%
data_present[(data_present['Lonely_Present']=='Disagree') & 
             (data_present['Spent_onli_Present']=='Few hours a day')].describe(include='O')
# Out:
#           Age                 Income         Emp_stat_Present Gender  \
# count      71                     71                       71     71
# unique      6                      6                        7      2
# top     20-25  5 - 10 lakh per annum  Private Sector Employee   Male
# freq       34                     18                       36     36
#
#        Marital_status        Loc Notice_things_Present All_angles_Present  \
# count              71         71                    71                 71
# unique              2         20                     5                  4
# top                No  Telangana                 Agree              Agree
# freq               43         37                    31                 41
#
#        Sincere_prod_Present Lonely_Present  ... Basic_medications_Present  \
# count                    71             71  ...                        71
# unique                    5              1  ...                         4
# ...

# %%
data_present[(data_present['Lonely_Present']=='Strongly Agree') & 
             (data_present['Meeting_ppl_Present']=='Strongly Agree')]
# Out:
#       ID    Age                                    Income  \
# 99   100  20-25  I don't earn right now (maybe in future)
# 121  122    55+                    10 - 20 lakh per annum
# 127  128    55+                     5 - 10 lakh per annum
# 150  151  25-30                      3 - 5 lakh per annum
# 166  167  20-25                      3 - 5 lakh per annum
# 221  222  20-25                      3 - 5 lakh per annum
# 227  228  20-25  I don't earn right now (maybe in future)
# 247  248  25-30  I don't earn right now (maybe in future)
# 255  256  20-25  I don't earn right now (maybe in future)
# 329  330  20-25                    Under 3 lakh per annum
# 358  359  25-30  I don't earn right now (maybe in future)
# 363  364  30-35                    Under 3 lakh per annum
# 415  416    55+                        20+ lakh per annum
# 478  479  25-30                      3 - 5 lakh per annum
# 492  493  20-25  I don't earn right now (maybe in future)
# ...

# %%
data_present[(data_present['Lonely_Present']=='Strongly Agree') & 
             (data_present['Meeting_ppl_Present']=='Strongly Agree')][.describe(include='O')]
# Out:
#   File "<ipython-input-74-5159ad92ca82>", line 2
#     (data_present['Meeting_ppl_Present']=='Strongly Agree')][.describe(include='O')]
#                                                              ^
# SyntaxError: invalid syntax

# %%
'''
1.we can observe that overall the number of people feeling lonely almost got doubled due to the pandemic
2.we can also observe that within the people who are strongly aggreing that they are feeling lonely currently,also
strongly agreed on the point that they enjoy meeting new people in the current situation as well
3.From this we can deduce that the strong restrictions of social distancing, staying away from people , can actually
be the potential cause of this lonliness.
4.Interestingly, we can observe from the plot of time spent online, that people who are spending most of the
time online are tending towards feeling more lonely and the ones who completely disagreed on the feeling of
lonliness are spending only few hours online, not actually isolating themselves completely.

If we dig deep into the demographics of the people who are feeling more lonely and spending more time on internet,
we can observe that :-

A.mostly students and private sector employees who are in their early 20s and in their early phase of career are
tending to show this behaviour. They seem completely directionless to actually waste so much time spending
online inorder to overcome their feeling of lonliness.
B.whereas , the population which disagreed on lonliness but still allocate a few hours of their daily life spending 
online, are dominated by the ones who are in their late 20s and have a stable income, they are the ones who probably
are busy working from home and have plans and a direction in life and seem to balancing everything in life.

If we dig further deep into this category of people who are feeling lonely due to lack of socialisation and 
observe their personality, we can observe :-

A.The private sector employees in the age group 20-25 are dominant, fair enough as the younger generations are the
ones who believe more in socialising and often hangout in groups

'''

# %% [markdown]
# ### 2. Observing interests of people and how did they change

# %%
# columns associated with interests
data_present.columns
# Out:
# Index(['ID', 'Age', 'Income', 'Emp_stat_Present', 'Gender', 'Marital_status',
#        'Loc', 'Notice_things_Present', 'All_angles_Present',
#        'Sincere_prod_Present', 'Lonely_Present', 'Worry_health_Present',
#        'Charity_Present', 'New_env_Present', 'Meeting_ppl_Present',
#        'Hob_interests_Present', 'Surveys_Present', 'Spent_onli_Present',
#        'WFH_office_Present', 'Ethu_Present', 'Income_Change',
#        'Smoking_hab_Present', 'Drinking_hab_Present', 'Sleeping_hab_Present',
#        'Healthy_Lifestyle_Present', 'Medi_pref_Present',
#        'Pol_interest_Present', 'Internet_interest_Present',
#        'Economy_Manag_intrst_Present', 'Medicine_intrst_Present',
#        'Religion_intrst_Present', 'Save_all_money_Present',
#        'Brand_non-brand_Present', 'Food_pref_Present',
#        'Mode_of_transport_Present', 'Basic_medications_Present',
#        'Digital_content_Present', 'Active_Investor_Present',
# ...

# %%
'Internet_interest_Before',

# %%
intrst_in_pol_before_labels = ((data_before['Pol_interest_Before'].value_counts()/len(data_before['Pol_interest_Before'])
                                )*100).index

intrst_in_pol_before = ((data_before['Pol_interest_Before'].value_counts()/len(data_before['Pol_interest_Before'])
                                )*100).values

# %%
intrst_in_pol_present_labels = ((data_present['Pol_interest_Present'].value_counts()/len(data_present['Pol_interest_Present'])
                                )*100).index

intrst_in_pol_present = ((data_present['Pol_interest_Present'].value_counts()/len(data_present['Pol_interest_Present'])
                                )*100).values

# %%
transition_PolIntrst_status = pd.crosstab(index=data_before['Pol_interest_Before'],
                                               columns=data_present['Pol_interest_Present'],
                                               margins=True, margins_name="Total"
            )

# %%
transition_PolIntrst_status
# Out:
# Pol_interest_Present   Moderately interested  Neutral  No Data  \
# Pol_interest_Before
# Moderately interested                     94       13        2
# Neutral                                   21      117        0
# No Data                                    1        1        7
# Not interested                            19       17        0
# Very interested                            7        2        0
# Total                                    142      150        9
#
# Pol_interest_Present   Not interested  Very interested  Total
# Pol_interest_Before
# Moderately interested               7               17    133
# Neutral                             6                5    149
# No Data                             2                0     11
# Not interested                    167                3    206
# Very interested                     1               42     52
# Total                             183               67    551

# %%
fig2,axes2=plt.subplots(1,2,figsize=(20,15))
axes2[0].pie(intrst_in_pol_before,
        labels=intrst_in_pol_before_labels,explode=[0,0,0,0,0],autopct='%1.2f%%')
axes2[1].pie(intrst_in_pol_present,labels=intrst_in_pol_present_labels,explode=[0,0,0,0,0],autopct='%1.2ff%%')

axes2[0].set_title('percentage of people showing interest in politics before the pandemic')
axes2[1].set_title('percentage of people showing interest in politics currently')

plt.show()

# %%
not_intrst_in_pol_before = data_before[data_before['Pol_interest_Before'] == 'Not interested']['ID'].values

# %%
intrst_in_pol_prsnt = data_present[(data_present['Pol_interest_Present'] == 'Very interested') |
            (data_present['Pol_interest_Present'] == 'Moderately interested')]['ID'].values

# %%
changed_ppl_ID = []

for i in range(len(intrst_in_pol_prsnt)):
    if intrst_in_pol_prsnt[i] in not_intrst_in_pol_before:
        changed_ppl_ID.append(intrst_in_pol_prsnt[i])
    else:
        continue

# %%
# demographics of people whose interest in politics changed
for i in changed_ppl_ID:
    data=data.append(data_present[data_present['ID'] == i].iloc[:,0:7])

# %%
data.iloc[1:,:]
# Out:
#       ID    Age                                    Income  \
# 7      8  20-25                    10 - 20 lakh per annum
# 78    79  20-25  I don't earn right now (maybe in future)
# 83    84  20-25  I don't earn right now (maybe in future)
# 89    90  20-25  I don't earn right now (maybe in future)
# 154  155  20-25                                   No Data
# 161  162  20-25  I don't earn right now (maybe in future)
# 201  202  30-35                    Under 3 lakh per annum
# 221  222  20-25                      3 - 5 lakh per annum
# 261  262  20-25                        20+ lakh per annum
# 285  286  40-55                      3 - 5 lakh per annum
# 340  341  20-25                     5 - 10 lakh per annum
# 365  366  20-25                      3 - 5 lakh per annum
# 367  368  20-25                        20+ lakh per annum
# 373  374  40-55                      3 - 5 lakh per annum
# 454  455  40-55                        20+ lakh per annum
# ...

# %%
'''
while majority of the people have shown the same amount of interest towards politics before and currently,
we can observe a slight change where a few people who were not at all interested in politics earlier are now showing
moderate or high interest in politics, they can be interested towards the governance or the administration, interested
in knowing the measures government is taking to curb the situation

we can also say that they are preferring to be more politically awared to not only abide by the rules that government
is asking to follow but also to know how efficiently the situation is being handled by the people's representatives.


we dig a little bit deep and understand the specific demographics as of who are the ones who has all of a sudden
started showing interest in politics we can see that :-

It is majorly dominated by youth who are in their early 20s and also can be observed from their income levels that
they are in their early phase of their career, even though this is a very specific change and also very minimal
and has no assurance of sustainance , it can be infered that the pandemic did actually strike a chord for them to
show this drastic change.


Plasma donors volnteers, recently people took to twitter and explained the situation in hyd to the governor asking her
to take action, the intensity of this actually led to the governor conversing with the CM, this shows assertiveness
like never before
'''

# %% [markdown]
# ### 3.Mixing behavioural analysis and business(spending patterns)

# %%
# interest in economy and management
sns.countplot(data_before['Economy_Manag_intrst_Before'])

# %%
sns.countplot(data_present['Economy_Manag_intrst_Present'])

# %%
intrst_in_eco_before_labels = ((data_before['Economy_Manag_intrst_Before'].value_counts()/len(data_before['Economy_Manag_intrst_Before'])
                                )*100).index

intrst_in_eco_before = ((data_before['Economy_Manag_intrst_Before'].value_counts()/len(data_before['Economy_Manag_intrst_Before'])
                                )*100).values

# %%
intrst_in_eco_present_labels = ((data_present['Economy_Manag_intrst_Present'].value_counts()/len(data_present['Economy_Manag_intrst_Present'])
                                )*100).index

intrst_in_eco_present = ((data_present['Economy_Manag_intrst_Present'].value_counts()/len(data_present['Economy_Manag_intrst_Present'])
                                )*100).values

# %%
transition_Eco_Management_Intrst_status = pd.crosstab(index=data_before['Economy_Manag_intrst_Before'],
                                               columns=data_present['Economy_Manag_intrst_Present'],
                                               margins=True, margins_name="Total"
            )

# %%
transition_Eco_Management_Intrst_status
# Out:
# Economy_Manag_intrst_Present  Moderately interested  Neutral  No Data  \
# Economy_Manag_intrst_Before
# Moderately interested                           140        5        1
# Neutral                                          34      145        0
# No Data                                           0        2       12
# Not interested                                   10        8        0
# Very interested                                   8        0        0
# Total                                           192      160       13
#
# Economy_Manag_intrst_Present  Not interested  Very interested  Total
# Economy_Manag_intrst_Before
# Moderately interested                      1               31    178
# Neutral                                    8                8    195
# No Data                                    0                1     15
# Not interested                            47                3     68
# Very interested                            0               87     95
# ...

# %%
fig2,axes2=plt.subplots(1,2,figsize=(20,15))
axes2[0].pie(intrst_in_eco_before,
        labels=intrst_in_eco_before_labels,explode=[0,0,0,0,0],autopct='%1.2f%%')
axes2[1].pie(intrst_in_eco_present,labels=intrst_in_eco_present_labels,explode=[0,0,0,0,0],autopct='%1.2ff%%')

axes2[0].set_title('percentage of people showing interest in economy and management before the pandemic')
axes2[1].set_title('percentage of people showing interest in economy and management currently')

plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_before['Active_Investor_Before'],hue='Economy_Manag_intrst_Before',data=data_before)

# %%
#economy
Save_all_money_Present,Economy_Manag_intrst_Before, 
active investor,Spend_on_Luxury_Present,Income,Emp_stat_Present

# %%
save_money_before_labels = ((data_before['Save_all_money_Before'].value_counts()/len(data_before['Save_all_money_Before'])
                                )*100).index

save_money_before = ((data_before['Save_all_money_Before'].value_counts()/len(data_before['Save_all_money_Before'])
                                )*100).values


save_money_present_labels = ((data_present['Save_all_money_Present'].value_counts()/len(data_present['Save_all_money_Present'])
                                )*100).index

save_money_present = ((data_present['Save_all_money_Present'].value_counts()/len(data_present['Save_all_money_Present'])
                                )*100).values

# %%
save_money_present
# Out:
# array([35.75317604, 30.30852995, 19.23774955,  6.53357532,  5.4446461 ,
#         2.72232305])

# %%
transition_matrix_saving_money_status = pd.crosstab(index=data_before['Save_all_money_Before'],
                                               columns=data_present['Save_all_money_Present'],
                                               margins=True, margins_name="Total",normalize=True
            )*100

# %%
transition_matrix_saving_money_status
# Out:
# Save_all_money_Present      Agree  Disagree    Neutral  Strongly Agree  \
# Save_all_money_Before
# Agree                   21.455224  0.559701   1.492537        5.223881
# Disagree                 5.223881  4.850746   3.731343        1.305970
# Neutral                  8.768657  0.559701  24.253731        2.985075
# No Data                  0.186567  0.186567   0.559701        0.000000
# Strongly Agree           0.000000  0.186567   0.000000        9.701493
# Strongly disagree        1.119403  0.373134   1.119403        0.559701
# Total                   36.753731  6.716418  31.156716       19.776119
#
# Save_all_money_Present  Strongly disagree       Total
# Save_all_money_Before
# Agree                            0.186567   28.917910
# Disagree                         0.373134   15.485075
# Neutral                          0.932836   37.500000
# No Data                          0.000000    0.932836
# Strongly Agree                   0.186567   10.074627
# ...

# %%
fig2,axes2=plt.subplots(1,2,figsize=(20,15))
axes2[0].pie(save_money_before,
        labels=save_money_before_labels,explode=[0,0.1,0,0.1,0,0],autopct='%1.2f%%')
axes2[1].pie(save_money_present,labels=save_money_present_labels,explode=[0.1,0,0.1,0,0,0],autopct='%1.2ff%%')

axes2[0].set_title('percentage of people showing interest in saving before the pandemic')
axes2[1].set_title('percentage of people showing interest in saving currently')

plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_present['Income_Change'],hue='Save_all_money_Present',data=data_present)

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_present['Track_Household_exp_Present'],hue='Save_all_money_Present',data=data_present)

# %%
data_before[data_before['ID']==468]
# Out:
#       ID    Age              Income Emp_stat_Before Gender Marital_status  \
# 467  468  30-35  20+ lakh per annum   Self-Employed   Male            Yes
#
#              Loc Notice_things_Before  All_angles_Before Sincere_prod_Before  \
# 467  Chattisgarh    Strongly disagree  Strongly disagree   Strongly disagree
#
#      ...    Mode_of_transport_Before Basic_medications_Before  \
# 467  ...  Public (Metro, govt e.t.c)                 Disagree
#
#     Digital_content_Before Active_Investor_Before Edu_instit_fee_Before  \
# 467               Disagree                  Agree              Disagree
#
#     Spend_on_gadgets_Before spend_on_Luxury_Before Track_Household_exp_Before  \
# 467                   Agree                  Agree                      Maybe
#
#     Domestic_help_Before Spending_kind_Before
# 467                  6.0      Medium spending
#
# [1 rows x 43 columns]

# %%
data_present[((data_present['Save_all_money_Present'] == 'Strongly Agree') | 
              (data_present['Save_all_money_Present'] == 'Agree')) & 
            (data_present['Income_Change']=='Decreased') & (data_present['Income']=='20+ lakh per annum')]
# Out:
#       ID    Age              Income                         Emp_stat_Present  \
# 26    27  20-25  20+ lakh per annum                            Self-Employed
# 191  192    55+  20+ lakh per annum                   Public Sector Employee
# 265  266  40-55  20+ lakh per annum                  Private Sector Employee
# 288  289  40-55  20+ lakh per annum                  Private Sector Employee
# 302  303  40-55  20+ lakh per annum                   Public Sector Employee
# 352  353  35-40  20+ lakh per annum                  Private Sector Employee
# 404  405    55+  20+ lakh per annum                  Private Sector Employee
# 444  445  30-35  20+ lakh per annum                  Private Sector Employee
# 451  452  40-55  20+ lakh per annum                            Self-Employed
# 453  454    55+  20+ lakh per annum                            Self-Employed
# 454  455  40-55  20+ lakh per annum                            Self-Employed
# ...

# %%
'''
from the above graphs , we can notice a drastic change wrt saving the money :-
1.The number of people trying to save the money currently almost got doubled if not exactly doubled
2.It has also been observed that people with both reduced and same income levels are showing interest in saving
currently and are keeping track of household expenses to facilitate this process.


If we dig deep and understand the category of people who are saving due to decreased in income levels, we can observe
that :-

1.It include all the income levels from under 3lakh to 20+, all of them are affected negatively income wise,but
majority of them who got effected are theprivate sector employees earning between 5-10 lakh per annum, reason
can be layoffs or salary cuts.

2. when the demographics are further analysed to understand the reasons for decreased income, it was observed that 
majority of the people earnin 20+ per annum earlier who are now facing income cuts are the ones who are self employed
, these are the people belonging to business class and they had to either shut their businesses or are facing losses
as the spending pattern and consumption as observed above reduced drastically.

(we didnt question them in detail as to which sector their business belongs to to give a more specific analysis.)

'''

# %%
data_present.columns
# Out:
# Index(['ID', 'Age', 'Income', 'Emp_stat_Present', 'Gender', 'Marital_status',
#        'Loc', 'Notice_things_Present', 'All_angles_Present',
#        'Sincere_prod_Present', 'Lonely_Present', 'Worry_health_Present',
#        'Charity_Present', 'New_env_Present', 'Meeting_ppl_Present',
#        'Hob_interests_Present', 'Surveys_Present', 'Spent_onli_Present',
#        'WFH_office_Present', 'Ethu_Present', 'Income_Change',
#        'Smoking_hab_Present', 'Drinking_hab_Present', 'Sleeping_hab_Present',
#        'Healthy_Lifestyle_Present', 'Medi_pref_Present',
#        'Pol_interest_Present', 'Internet_interest_Present',
#        'Economy_Manag_intrst_Present', 'Medicine_intrst_Present',
#        'Religion_intrst_Present', 'Save_all_money_Present',
#        'Brand_non-brand_Present', 'Food_pref_Present',
#        'Mode_of_transport_Present', 'Basic_medications_Present',
#        'Digital_content_Present', 'Active_Investor_Present',
# ...

# %%
cols1=['Emp_stat_Present','Food_pref_Present','Mode_of_transport_Present','Basic_medications_Present','Digital_content_Present',
'Spend_on_Luxury_Present','Edu_instit_fee_Present','Spending_kind_Present']

# %%
cols2=['Emp_stat_Before','Food_pref_Before','Mode_of_transport_Before','Basic_medications_Before','Digital_content_Before',
'spend_on_Luxury_Before','Edu_instit_fee_Before','Spending_kind_Before']

# %%
# people with decreased income spending patterns and preferences - currently
data_present[data_present['Income_Change']=='Decreased'][cols1].describe(include='O')
# Out:
#                Emp_stat_Present Food_pref_Present Mode_of_transport_Present  \
# count                       183               183                       183
# unique                        7                 3                         4
# top     Private Sector Employee     Home - Cooked                  Personal
# freq                         81               165                       116
#
#        Basic_medications_Present Digital_content_Present  \
# count                        183                     183
# unique                         4                       4
# top                        Agree                   Agree
# freq                         116                     104
#
#        Spend_on_Luxury_Present Edu_instit_fee_Present Spending_kind_Present
# count                      183                    183                   183
# unique                       4                      6                     7
# ...

# %%
decreased_income_ID = data_present[data_present['Income_Change']=='Decreased']['ID'].values

# %%
data_new = pd.DataFrame(columns=cols2)

for i in decreased_income_ID:
    data_new=data_new.append(data_before[data_before['ID'] == i][cols2])

# %%
# people with decreased income spending patterns and preferences - previously
data_new.describe(include='O')
# Out:
#                 Emp_stat_Before            Food_pref_Before  \
# count                       183                         183
# unique                        7                           3
# top     Private Sector Employee  Outside (Online & Offline)
# freq                        107                          97
#
#        Mode_of_transport_Before Basic_medications_Before  \
# count                       183                      183
# unique                        4                        4
# top        Private (cabs e.t.c)                    Agree
# freq                         65                       72
#
#        Digital_content_Before spend_on_Luxury_Before Edu_instit_fee_Before  \
# count                     183                    183                   183
# unique                      4                      4                     6
# top                   Neutral                  Agree                 Agree
# ...

# %%
# people with same income spending patterns and preferences - previously

# %%
same_income_ID = data_present[data_present['Income_Change']=='Same or no effect']['ID'].values

# %%
data_new1 = pd.DataFrame(columns=cols2)

for i in same_income_ID:
    data_new1=data_new1.append(data_before[data_before['ID'] == i][cols2])

# %%
data_new1.describe(include='O')
# Out:
#                 Emp_stat_Before Food_pref_Before Mode_of_transport_Before  \
# count                       320              320                      320
# unique                        7                3                        4
# top     Private Sector Employee    Home - Cooked     Private (cabs e.t.c)
# freq                        140              163                      117
#
#        Basic_medications_Before Digital_content_Before spend_on_Luxury_Before  \
# count                       320                    320                    320
# unique                        4                      4                      4
# top                       Agree                Neutral                Neutral
# freq                        165                    110                    120
#
#        Edu_instit_fee_Before Spending_kind_Before
# count                    320                  320
# unique                     6                    7
# top                    Agree      Medium spending
# ...

# %%
# people with same income spending patterns and preferences - currently
data_present[data_present['Income_Change']=='Same or no effect'][cols1].describe(include='O')
# Out:
#                Emp_stat_Present Food_pref_Present Mode_of_transport_Present  \
# count                       320               320                       320
# unique                        7                 3                         4
# top     Private Sector Employee     Home - Cooked                  Personal
# freq                        131               282                       175
#
#        Basic_medications_Present Digital_content_Present  \
# count                        320                     320
# unique                         4                       4
# top                        Agree                   Agree
# freq                         216                     175
#
#        Spend_on_Luxury_Present Edu_instit_fee_Present Spending_kind_Present
# count                      320                    320                   320
# unique                       4                      6                     7
# ...

# %%
# people with increased income spending patterns and preferences - previously
increased_income_ID = data_present[data_present['Income_Change']=='Increased']['ID'].values

# %%
data_new2 = pd.DataFrame(columns=cols2)

for i in increased_income_ID:
    data_new2=data_new2.append(data_before[data_before['ID'] == i][cols2])

# %%
data_new2.describe(include='O')
# Out:
#                 Emp_stat_Before            Food_pref_Before  \
# count                        17                          17
# unique                        2                           2
# top     Private Sector Employee  Outside (Online & Offline)
# freq                         16                          12
#
#        Mode_of_transport_Before Basic_medications_Before  \
# count                        17                       17
# unique                        3                        3
# top                    Personal                  Neutral
# freq                          7                        8
#
#        Digital_content_Before spend_on_Luxury_Before Edu_instit_fee_Before  \
# count                      17                     17                    17
# unique                      3                      3                     5
# top                  Disagree                  Agree        Strongly agree
# ...

# %%
# people with increased income spending patterns and preferences - currently
data_present[data_present['Income_Change']=='Increased'][cols1].describe(include='O')
# Out:
#                Emp_stat_Present Food_pref_Present Mode_of_transport_Present  \
# count                        17                17                        17
# unique                        3                 2                         4
# top     Private Sector Employee     Home - Cooked                  Personal
# freq                         15                11                         9
#
#        Basic_medications_Present Digital_content_Present  \
# count                         17                      17
# unique                         3                       3
# top                        Agree                   Agree
# freq                           9                       8
#
#        Spend_on_Luxury_Present Edu_instit_fee_Present Spending_kind_Present
# count                       17                     17                    17
# unique                       3                      4                     4
# ...

# %%
'''


Now going further, if we specifically analyse the areas where they are more interested in spending their money on 
currently :-

1.People with decreased income levels has shown a significant changes of shifting from spending on luxury items to
not investing on them, fom using cabs to opting for personal transport, from ordering food online to preferring
home cooked food

2.Whereas the people whose income didnot get affected neither negatively nor positively still continue to
prefer online food and private transport but has cut down spendings on luxury items.

3.Now there are another interesting category of people whose income increased during the pandemic and are still
affording to spend on luxury items and always used to use their personal transport to work

All these insights are given keeping in mind the dominant personalities of each group

If we further analyse the spending group of people whose income increased and are spending almost in the same way as
before, the following things has been observed :-

A. Although on an average the spending kind showed that they turned towards medium spending, internally it has been 
observed there are significant high spending people as well (all of them are unmarried)
,and 70% of this category agreed that they still spend on luxury.

B. All of them are private sector employees and has recieved a salary rise while being in the same sector, most of
them belong to the income group 5-10 lakh per annum between age 25-30 years, this can be due to job switches or 
hikes.

'''

# %%
data_new2
# Out:
#              Emp_stat_Before            Food_pref_Before  \
# 158  Private Sector Employee  Outside (Online & Offline)
# 206  Private Sector Employee               Home - Cooked
# 219  Private Sector Employee  Outside (Online & Offline)
# 222  Private Sector Employee  Outside (Online & Offline)
# 312  Private Sector Employee  Outside (Online & Offline)
# 329  Private Sector Employee  Outside (Online & Offline)
# 334  Private Sector Employee               Home - Cooked
# 337  Private Sector Employee               Home - Cooked
# 341  Private Sector Employee  Outside (Online & Offline)
# 414  Private Sector Employee  Outside (Online & Offline)
# 415  Private Sector Employee  Outside (Online & Offline)
# 432            Self-Employed               Home - Cooked
# 438  Private Sector Employee  Outside (Online & Offline)
# 441  Private Sector Employee               Home - Cooked
# 462  Private Sector Employee  Outside (Online & Offline)
# ...

# %%
data_present[data_present['Income_Change']=='Increased']
# Out:
#       ID    Age                  Income         Emp_stat_Present  \
# 158  159    55+      20+ lakh per annum  Private Sector Employee
# 206  207  25-30   5 - 10 lakh per annum  Private Sector Employee
# 219  220  25-30   5 - 10 lakh per annum  Private Sector Employee
# 222  223  25-30   5 - 10 lakh per annum  Private Sector Employee
# 312  313  20-25  Under 3 lakh per annum  Private Sector Employee
# 329  330  20-25  Under 3 lakh per annum  Private Sector Employee
# 334  335  20-25    3 - 5 lakh per annum  Private Sector Employee
# 337  338  30-35   5 - 10 lakh per annum  Private Sector Employee
# 341  342  25-30    3 - 5 lakh per annum  Private Sector Employee
# 414  415    55+      20+ lakh per annum  Private Sector Employee
# 415  416    55+      20+ lakh per annum  Private Sector Employee
# 432  433  25-30  Under 3 lakh per annum            Self-Employed
# 438  439  20-25   5 - 10 lakh per annum                  No Data
# ...

# %%
fig2,axes2=plt.subplots(1,2,figsize=(15,7))
axes2[0].pie(Income_Change,
        labels=Income_Change_labels,explode=[0,0.1,0],autopct='%1.2f%%')
axes2[1].pie(Income_Change,
        labels=Income_Change_labels,explode=[0,0.1,0],autopct='%1.2f%%')


axes2[0].set_title('Income_change proportion')


plt.show()

# %%
Income_Change_labels = ((data_present['Income_Change'].value_counts()/data_present['Income_Change'].value_counts().sum())*100).index

Income_Change = ((data_present['Income_Change'].value_counts()/data_present['Income_Change'].value_counts().sum())*100).values

# %%
(data_present['Income_Change'].value_counts()/data_present['Income_Change'].value_counts().sum())*100

# %%
transition_enthu_to_startnew = pd.crosstab(index=data_before['Enthu_Before'],
                                               columns=data_present['Ethu_Present'],
                                               margins=True, margins_name="Total")

# %%
# 'Ethu_Present',change in income, employement status
plt.figure(figsize=(15,7))
sns.countplot(data_present['Ethu_Present'],hue='Income_Change',data=data_present)
plt.show()

# %%
Emp_stat_labels = ((data_present['Emp_stat_Present'].value_counts()/data_present['Emp_stat_Present'].value_counts().sum())*100).index

Emp_stat_Change = ((data_present['Emp_stat_Present'].value_counts()/data_present['Emp_stat_Present'].value_counts().sum())*100).values

# %%
fig2,axes2=plt.subplots(1,1,figsize=(20,8))
axes2.pie(Emp_stat_Change,
        labels=Emp_stat_labels,explode=[0,0,0,0,0,0],autopct='%1.2f%%')

axes2.set_title('Employment status proportion')


plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_present['Ethu_Present'],hue='Emp_stat_Present',data=data_present)
plt.show()

# %%
sns.countplot(data_present['Ethu_present'])

# %%
(data_present['Emp_stat_Present'].value_counts()/data_present['Emp_stat_Present'].value_counts().sum())*100
# Out:
# Private Sector Employee                        47.695391
# Student                                        17.234469
# Self-Employed                                  11.823647
# Public Sector Employee                         11.022044
# Unemployed (currently looking for work)         9.018036
# Unemployed (not currently looking for work)     3.206413
# Name: Emp_stat_Present, dtype: float64

# %%
data_present.columns
# Out:
# Index(['ID', 'Age', 'Income', 'Emp_stat_Present', 'Gender', 'Marital_status',
#        'Loc', 'Notice_things_Present', 'All_angles_Present',
#        'Sincere_prod_Present', 'Lonely_Present', 'Worry_health_Present',
#        'Charity_Present', 'New_env_Present', 'Meeting_ppl_Present',
#        'Hob_interests_Present', 'Surveys_Present', 'Spent_onli_Present',
#        'WFH_office_Present', 'Ethu_Present', 'Income_Change',
#        'Smoking_hab_Present', 'Drinking_hab_Present', 'Sleeping_hab_Present',
#        'Healthy_Lifestyle_Present', 'Medi_pref_Present',
#        'Pol_interest_Present', 'Internet_interest_Present',
#        'Economy_Manag_intrst_Present', 'Medicine_intrst_Present',
#        'Religion_intrst_Present', 'Save_all_money_Present',
#        'Brand_non-brand_Present', 'Food_pref_Present',
#        'Mode_of_transport_Present', 'Basic_medications_Present',
#        'Digital_content_Present', 'Active_Investor_Present',
# ...

# %%
len(data_present[(data_present['Ethu_Present'] == 'Strongly Agree') |
             (data_present['Ethu_Present'] == 'Agree')])
# Out:
# 343

# %%
data_present[((data_present['Ethu_Present'] == 'Strongly Agree') |
             (data_present['Ethu_Present'] == 'Agree')) & (data_present['Age']=='20-25')].describe(include='O')
# Out:
#           Age                                    Income  \
# count     178                                       178
# unique      1                                         7
# top     20-25  I don't earn right now (maybe in future)
# freq      178                                        81
#
#                Emp_stat_Present  Gender Marital_status        Loc  \
# count                       178     178            178        178
# unique                        7       3              3         22
# top     Private Sector Employee  Female             No  Telangana
# freq                         60      97            168        121
#
#        Notice_things_Present All_angles_Present Sincere_prod_Present  \
# count                    178                178                  178
# unique                     6                  5                    6
# top           Strongly agree              Agree                Agree
# freq                      75                 86                   89
#
# ...

# %%
data_present[((data_present['Ethu_Present'] == 'Strongly Agree') |
             (data_present['Ethu_Present'] == 'Agree')) & (data_present['Age']=='25-30')].describe(include='O')
# Out:
#           Age                 Income         Emp_stat_Present Gender  \
# count      62                     62                       62     62
# unique      1                      7                        6      4
# top     25-30  5 - 10 lakh per annum  Private Sector Employee   Male
# freq       62                     27                       43     34
#
#        Marital_status        Loc Notice_things_Present All_angles_Present  \
# count              62         62                    62                 62
# unique              3         23                     5                  5
# top                No  Telangana                 Agree     Strongly Agree
# freq               44         23                    32                 25
#
#        Sincere_prod_Present Lonely_Present Worry_health_Present  \
# count                    62             62                   62
# unique                    5              5                    5
# ...

# %%
data_present[((data_present['Ethu_Present'] == 'Strongly Agree') |
             (data_present['Ethu_Present'] == 'Agree')) & (data_present['Age']=='30-35')].describe(include='O')
# Out:
#           Age              Income         Emp_stat_Present  Gender  \
# count      33                  33                       33      33
# unique      1                   7                        4       2
# top     30-35  20+ lakh per annum  Private Sector Employee  Female
# freq       33                   9                       23      18
#
#        Marital_status          Loc Notice_things_Present All_angles_Present  \
# count              33           33                    33                 33
# unique              2           17                     4                  5
# top               Yes  Maharashtra        Strongly agree     Strongly Agree
# freq               26            6                    16                 17
#
#        Sincere_prod_Present     Lonely_Present Worry_health_Present  \
# count                    33                 33                   33
# unique                    5                  6                    6
# ...

# %%
data_present[((data_present['Ethu_Present'] == 'Strongly Agree') |
             (data_present['Ethu_Present'] == 'Agree')) & (data_present['Age']=='35-40')].describe(include='O')
# Out:
#           Age                  Income         Emp_stat_Present Gender  \
# count      17                      17                       17     17
# unique      1                       5                        4      2
# top     35-40  10 - 20 lakh per annum  Private Sector Employee   Male
# freq       17                       5                        9     10
#
#        Marital_status        Loc Notice_things_Present All_angles_Present  \
# count              17         17                    17                 17
# unique              1         10                     6                  3
# top               Yes  Telangana        Strongly agree     Strongly Agree
# freq               17          5                     6                  8
#
#        Sincere_prod_Present Lonely_Present Worry_health_Present  \
# count                    17             17                   17
# unique                    2              4                    5
# ...

# %%
data_present[((data_present['Ethu_Present'] == 'Strongly Agree') |
             (data_present['Ethu_Present'] == 'Agree')) & (data_present['Age']=='40-55')].describe(include='O')
# Out:
#           Age              Income         Emp_stat_Present Gender  \
# count      41                  41                       41     41
# unique      1                   7                        6      3
# top     40-55  20+ lakh per annum  Private Sector Employee   Male
# freq       41                  12                       17     22
#
#        Marital_status        Loc Notice_things_Present All_angles_Present  \
# count              41         41                    41                 41
# unique              3         11                     3                  4
# top               Yes  Telangana        Strongly agree     Strongly Agree
# freq               38         18                    20                 20
#
#        Sincere_prod_Present     Lonely_Present Worry_health_Present  \
# count                    41                 41                   41
# unique                    3                  5                    5
# ...

# %%
data_present[((data_present['Ethu_Present'] == 'Strongly Agree') |
             (data_present['Ethu_Present'] == 'Agree')) & (data_present['Age']=='55+')].describe(include='O')
# Out:
#         Age                  Income         Emp_stat_Present Gender  \
# count    12                      12                       12     12
# unique    1                       4                        5      3
# top     55+  10 - 20 lakh per annum  Private Sector Employee   Male
# freq     12                       5                        6     10
#
#        Marital_status        Loc Notice_things_Present All_angles_Present  \
# count              12         12                    12                 12
# unique              1          6                     3                  2
# top               Yes  Telangana        Strongly agree              Agree
# freq               12          6                     8                  7
#
#        Sincere_prod_Present Lonely_Present Worry_health_Present  \
# count                    12             12                   12
# unique                    2              4                    5
# ...

# %%
transition_enthu_to_startnew
# Out:
# Ethu_Present       Agree  Disagree  Neutral  Strongly Agree  \
# Enthu_Before
# Agree                151        40       31              36
# Disagree               9        15        5               3
# Neutral               36         5       67              12
# No Data                3         0        0               0
# Strongly Agree        17         3       11              74
# Strongly disagree      2         0        2               0
# Total                218        63      116             125
#
# Ethu_Present       Strongly disagree  Total
# Enthu_Before
# Agree                              7    265
# Disagree                           2     34
# Neutral                            1    121
# No Data                            0      3
# Strongly Agree                     5    110
# Strongly disagree                  6     10
# Total                             21    543

# %%
ids_before_disagree = data_before[data_before['Enthu_Before']=='Disagree']['ID'].values

# %%
data_present.iloc[ids_before_disagree][(data_present['Ethu_Present']=='Agree') |
                                      (data_present['Ethu_Present']=='Strongly Agree')].describe(include='O')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#           Age                Income         Emp_stat_Present  Gender  \
# count      22                    22                       22      22
# unique      5                     7                        6       3
# top     20-25  3 - 5 lakh per annum  Private Sector Employee  Female
# freq       10                     7                       10      13
#
#        Marital_status        Loc Notice_things_Present All_angles_Present  \
# count              22         22                    22                 22
# unique              2          8                     5                  5
# top                No  Telangana                 Agree              Agree
# freq               14         13                    10                  8
#
#        Sincere_prod_Present     Lonely_Present Worry_health_Present  \
# ...

# %%
data_present.iloc[ids_before_disagree-1][(data_present['Ethu_Present']=='Agree') |
                                      (data_present['Ethu_Present']=='Strongly Agree')]
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       ID    Age                                    Income  \
# 13    14  20-25                      3 - 5 lakh per annum
# 45    46  20-25                     5 - 10 lakh per annum
# 63    64  20-25                     5 - 10 lakh per annum
# 78    79  20-25  I don't earn right now (maybe in future)
# 89    90  20-25  I don't earn right now (maybe in future)
# 122  123  20-25  I don't earn right now (maybe in future)
# 220  221  20-25  I don't earn right now (maybe in future)
# 281  282  20-25                    Under 3 lakh per annum
# 299  300  20-25  I don't earn right now (maybe in future)
# 318  319  20-25                        20+ lakh per annum
# 443  444  25-30                     5 - 10 lakh per annum
# 494  495  20-25  I don't earn right now (maybe in future)
#
# ...

# %%
len(data_present[data_present['Ethu_Present']=='No Data'])
# Out:
# 8

# %%
ids_before_agree = data_before[data_before['Enthu_Before']=='Agree']['ID'].values

# %%
ids_before_agree
# Out:
# array([  5,   8,  11,  12,  16,  21,  26,  27,  28,  32,  34,  36,  37,
#         39,  40,  42,  45,  51,  52,  53,  54,  56,  57,  58,  59,  62,
#         66,  67,  68,  72,  73,  75,  76,  77,  78,  84,  91,  92,  94,
#         96,  97, 104, 105, 109, 110, 112, 115, 116, 117, 119, 121, 122,
#        124, 125, 127, 128, 131, 137, 139, 140, 142, 143, 144, 145, 149,
#        150, 153, 154, 155, 160, 161, 163, 165, 166, 168, 171, 174, 175,
#        177, 178, 179, 180, 181, 182, 184, 187, 188, 190, 191, 194, 195,
#        196, 203, 211, 212, 213, 214, 218, 226, 228, 229, 231, 233, 236,
#        238, 240, 242, 247, 248, 249, 251, 253, 254, 255, 257, 258, 263,
#        264, 265, 266, 270, 271, 274, 278, 280, 281, 284, 286, 288, 289,
#        290, 291, 292, 293, 295, 296, 298, 299, 301, 302, 303, 308, 309,
#        311, 313, 314, 318, 321, 322, 324, 327, 328, 329, 331, 332, 334,
#        336, 337, 338, 339, 340, 341, 342, 343, 344, 352, 354, 358, 361,
# ...

# %%
len(data_present.iloc[ids_before_agree-1][(data_present['Ethu_Present']=='Disagree') | 
(data_present['Ethu_Present']=='Strongly Disagree')])
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 40

# %%
data_present.iloc[ids_before_agree-1][(data_present['Ethu_Present']=='Disagree') | 
(data_present['Ethu_Present']=='Strongly Disagree')]
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       ID    Age                                    Income  \
# 15    16  20-25                    10 - 20 lakh per annum
# 35    36  20-25  I don't earn right now (maybe in future)
# 50    51  20-25                    Under 3 lakh per annum
# 53    54  20-25  I don't earn right now (maybe in future)
# 56    57  35-40                    10 - 20 lakh per annum
# 58    59  20-25  I don't earn right now (maybe in future)
# 75    76  20-25  I don't earn right now (maybe in future)
# 115  116  20-25                      3 - 5 lakh per annum
# 124  125  40-55                        20+ lakh per annum
# 142  143  20-25                     5 - 10 lakh per annum
# 153  154  40-55                        20+ lakh per annum
# 170  171    55+                    10 - 20 lakh per annum
# 174  175  20-25  I don't earn right now (maybe in future)
# ...

# %%
'''
It has been observed fron the survey results that the enthusiasm to do something new is not dependent on a person's 
employment status and income change, therefore this shows that it is not only influenced by one's financial situation
,but can have different perspectives to it, from starting a new hobby , to making a new lifestyle choice,
health choice etc..

1.68% of the people who filled the survey, were interested in doing something new which now reduced
to 60%.

2.Even though there is an overall reduction , internally there is an incremental shift , where people who didnot agree
on doing something new before now started doing something new, we can observe the following charecteristics :-
2.A Employed females in the age group 20-30,mostly unmarried are showing the enthusiasm towards doing something new,
and all of them strongly agreed on having multiple hobbies currently and are also maintaining a healthy lifestyle.
2.They are showing interest towards buying branded food products which are generally costly, all while saving as much
money as they can as they have shown equal interest in economy management as well,
they also have strongly agreed that they are interested in medicinal aspects and are being more aware health-wise
THE WHOLE THING IN GENERAL EXPLAINS THE CHANGE IN THE WAY OF LIFE AS A RESULT OF THEIR ENTHUSIASM TOMAKE NEW CHANGES
IN LIFE.


3.Then there are sections which doesn't hold the enthusiasm of doing something new like before,these include people
in the age group 30-55 years, with a stable average income of 12 lakh per annum and are probably preferring not to
take risks by starting something new.


'''

# %%
# Internet interest, digital content,Change in data consumption,spending time online

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_present['Internet_interest_Present'],hue='Digital_content_Present',data=data_present)

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_present['Change_in_data_consumption'],hue='Digital_content_Present',data=data_present)

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_present['Spent_onli_Present'],hue='Digital_content_Present',data=data_present)

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_present['Age'],hue='Digital_content_Present',data=data_present)

# %%
plt.figure(figsize=(15,7))
sns.countplot(data_present['Marital_status'],hue='Spent_onli_Present',data=data_present)

# %%
(data_present['Digital_content_Present'].value_counts()/data_present['Digital_content_Present'].value_counts().sum())*100
# Out:
# Agree       54.083485
# Neutral     27.586207
# Disagree    16.152450
# No Data      2.177858
# Name: Digital_content_Present, dtype: float64

# %%
(data_before['Digital_content_Before'].value_counts()/data_before['Digital_content_Before'].value_counts().sum())*100
# Out:
# Neutral     35.390200
# Disagree    34.119782
# Agree       27.586207
# No Data      2.903811
# Name: Digital_content_Before, dtype: float64

# %%
data_present[(data_present['Marital_status']=='Yes') & (data_present['Spent_onli_Present']== 'Most of the day')].describe(include='O')
# Out:
#           Age                  Income         Emp_stat_Present Gender  \
# count      73                      73                       73     73
# unique      6                       7                        7      3
# top     40-55  10 - 20 lakh per annum  Private Sector Employee   Male
# freq       20                      19                       36     44
#
#        Marital_status        Loc Notice_things_Present All_angles_Present  \
# count              73         73                    73                 73
# unique              1         26                     6                  5
# top               Yes  Telangana        Strongly agree     Strongly Agree
# freq               73         25                    35                 35
#
#        Sincere_prod_Present Lonely_Present Worry_health_Present  \
# count                    73             73                   73
# unique                    4              5                    5
# ...

# %%
data_present[(data_present['Marital_status']=='Yes') & (data_present['Spent_onli_Present']== 'Most of the day')]['Emp_stat_Present'].value_counts()
# Out:
# Private Sector Employee                        36
# Public Sector Employee                         12
# Self-Employed                                  11
# No Data                                         6
# Unemployed (currently looking for work)         4
# Unemployed (not currently looking for work)     3
# Student                                         1
# Name: Emp_stat_Present, dtype: int64

# %%
data_present[data_present['Marital_status']=='Yes']['Emp_stat_Present'].value_counts()
# Out:
# Private Sector Employee                        104
# Public Sector Employee                          42
# Self-Employed                                   30
# No Data                                         15
# Unemployed (currently looking for work)         12
# Unemployed (not currently looking for work)     10
# Student                                          1
# Name: Emp_stat_Present, dtype: int64

# %%
data_present['Marital_status'].value_counts()
# Out:
# No         331
# Yes        214
# No Data      6
# Name: Marital_status, dtype: int64

# %%
len(data_before[(data_present['Marital_status']=='Yes') & (data_before['Spent_onli_Before']== 'Most of the day')])
# Out:
# 28

# %%
(data_before['Age'].value_counts()/data_before['Age'].value_counts().sum())*100
# Out:
# 20-25      47.731397
# 25-30      15.607985
# 40-55      14.882033
# 30-35      10.344828
# 35-40       5.807623
# 55+         5.263158
# No Data     0.362976
# Name: Age, dtype: float64

# %%
data_present[(data_present['Age']=='20-25') & (data_present['Digital_content_Present']=='Agree')].describe(include='O')
# Out:
#           Age                                    Income  \
# count     127                                       127
# unique      1                                         7
# top     20-25  I don't earn right now (maybe in future)
# freq      127                                        62
#
#                Emp_stat_Present  Gender Marital_status        Loc  \
# count                       127     127            127        127
# unique                        7       3              2         18
# top     Private Sector Employee  Female             No  Telangana
# freq                         42      74            118         84
#
#        Notice_things_Present All_angles_Present Sincere_prod_Present  \
# count                    127                127                  127
# unique                     5                  4                    6
# top           Strongly agree              Agree                Agree
# freq                      57                 61                   61
#
# ...

# %%
'''
1.There's an overall increment of 50% in the number of people preferring digital content than going outside and 
spending for entertainment.

2. 30% of the married people mostly males in the age group 40-55 years are showing great interest in spending time on 
internet and almost all of them agreed that they spend most of the day online irrespective of their employment status
(private sector,public sector,self employed, unemployed), earlier this count was only 13%.

3.If we go further and analyse the internet preferences of this age group, interestingly it has been observed in the
age group wise segmentation of digital entertainment preference, its the people in the age group 40-55 who are the
second highest to agree that they prefer digital content over going outside and spending for entertainment,considering
their proportion in the entire survey responses(14%) this is a very significant observation.

4.20-25 age group being the first highest to agree that they prefer digital content more than going outside,they exhibit
similar characteristics  of spending most of the day online and this group are dominated by unemployed females who have
irregular sleeping habits of late to bed and late to rise and are neutral towards maintaining a healthy lifestyle.

5.It can be inferred from above that, interestingly age groups 20-25 and 40-55 and above are spending more time online
watching digital content,the reason can be absolutely no responsibilities or reduction in the responsibilities
in both the age groups and having more time than ever to spend, people who are in their mid 30s groups have given 
very less priority to spending time online and watching digital content as they are surrounded with more 
responsibilities and less time to spend.

'''

# %% [markdown]
# ### 4.A OBSERVING HEALTH HABITS (SMOKING,DRINKING,SLEEPING, AND MAINTAINING A HEALTHY ROUTINE)

# %%
#smoking habits
plt.figure(figsize=(15,7))
sns.countplot(data_present['Smoking_hab_Present'])
plt.show()

# %%
ser1=data_before[data_before['Smoking_hab_Before']=='Current smoker']['Smoking_hab_Before']

# %%
IDs_smoker_before = data_before[data_before['Smoking_hab_Before']=='Current smoker']['ID']

# %%
smoker_status = pd.DataFrame()

# %%
ser2=data_present.iloc[IDs_smoker_before-1]['Smoking_hab_Present']

# %%
smoker_status['ID']=IDs_smoker_before

# %%
smoker_status['Smoking_hab_Before']=ser1

# %%
smoker_status['Smoking_hab_Present']=ser2

# %%
len(smoker_status[(smoker_status['Smoking_hab_Before']=='Current smoker') & 
              (smoker_status['Smoking_hab_Present']=='Former smoker')])
# Out:
# 15

# %%
transition_matrix_smoking_status = pd.DataFrame()

# %%
#Normalize by dividing all values by the sum of values.
#If passed 'index' will normalize over each row.
transition_matrix_smoking_status = pd.crosstab(index=data_before['Smoking_hab_Before'],
                                               columns=data_present['Smoking_hab_Present'],
                                               margins=True, margins_name="Total"
            )

# %%
transition_matrix_smoking_status
# Out:
# Smoking_hab_Present  Current smoker  Former smoker  Never smoked  \
# Smoking_hab_Before
# Current smoker                   17             15             2
# Former smoker                     3             22            12
# Never smoked                      2              0           393
# No Data                           0              1             3
# Tried smoking                     1              7            33
# Total                            23             45           443
#
# Smoking_hab_Present  Tried smoking  Total
# Smoking_hab_Before
# Current smoker                   2     36
# Former smoker                    2     39
# Never smoked                     7    402
# No Data                          0      4
# Tried smoking                   21     62
# Total                           32    543

# %%
never_smoked_before = data_before[data_before['Smoking_hab_Before']=='Never smoked']['ID'].values

# %%
tried_or_smoker_present = data_present[(data_present['Smoking_hab_Present']=='Tried smoking') | 
            
            (data_present['Smoking_hab_Present']=='Current smoker')]['ID'].values

# %%
current_smokers = []

# %%
for i_D in never_smoked_before:
    if i_D in tried_or_smoker_present:
        current_smokers.append(i_D-1)

# %%
data_present.iloc[current_smokers]
# Out:
#       ID    Age                                    Income  \
# 189  190  20-25                    Under 3 lakh per annum
# 278  279  40-55                        20+ lakh per annum
# 289  290  35-40                        20+ lakh per annum
# 365  366  20-25                      3 - 5 lakh per annum
# 447  448  30-35                    10 - 20 lakh per annum
# 452  453  30-35                    10 - 20 lakh per annum
# 456  457  20-25  I don't earn right now (maybe in future)
# 459  460    55+                     5 - 10 lakh per annum
# 462  463  40-55                        20+ lakh per annum
#
#                                 Emp_stat_Present  Gender Marital_status  \
# 189                      Private Sector Employee    Male             No
# 278                       Public Sector Employee  Female             No
# 289                      Private Sector Employee    Male            Yes
# 365                      Private Sector Employee  Female             No
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
data_present.iloc[current_smokers].describe(include='O')
# Out:
#           Age              Income         Emp_stat_Present Gender  \
# count       9                   9                        7      9
# unique      5                   6                        4      2
# top     20-25  20+ lakh per annum  Private Sector Employee   Male
# freq        3                   3                        4      5
#
#        Marital_status          Loc Notice_things_Present All_angles_Present  \
# count               9            9                     9                  9
# unique              2            5                     3                  3
# top                No  Chattisgarh                 Agree              Agree
# freq                5            3                     6                  7
#
#        Sincere_prod_Present Lonely_Present Worry_health_Present  \
# count                     9              9                    9
# unique                    3              3                    2
# ...

# %%
data_present.iloc[current_smokers].describe(include='O').loc['top',:]
# Out:
# Age                                                                 20-25
# Income                                                 20+ lakh per annum
# Emp_stat_Present                                  Private Sector Employee
# Gender                                                               Male
# Marital_status                                                         No
# Loc                                                           Chattisgarh
# Notice_things_Present                                               Agree
# All_angles_Present                                                  Agree
# Sincere_prod_Present                                                Agree
# Lonely_Present                                                      Agree
# Worry_health_Present                                                Agree
# Charity_Present                                                     Agree
# New_env_Present                                                  Disagree
# ...

# %%
prev_smokers = data_before[data_before['Smoking_hab_Before']=='Current smoker']['ID'].values

# %%
current_smokers = data_present[data_present['Smoking_hab_Present']=='Current smoker']['ID'].values

# %%
prev_current_smokers = []

# %%
for i_D in prev_smokers:
    if i_D in current_smokers:
        prev_current_smokers.append(i_D-1)

# %%
len(prev_current_smokers)
# Out:
# 17

# %%
data_present.iloc[prev_current_smokers]
# Out:
#       ID    Age                                    Income  \
# 1      2    55+                        20+ lakh per annum
# 80    81  20-25                      3 - 5 lakh per annum
# 113  114  20-25                     5 - 10 lakh per annum
# 154  155  20-25                                       NaN
# 181  182    55+                    10 - 20 lakh per annum
# 184  185  25-30  I don't earn right now (maybe in future)
# 186  187  40-55                        20+ lakh per annum
# 247  248  25-30  I don't earn right now (maybe in future)
# 282  283  25-30                      3 - 5 lakh per annum
# 298  299  35-40                        20+ lakh per annum
# 342  343    55+                     5 - 10 lakh per annum
# 364  365  40-55                        20+ lakh per annum
# 371  372  40-55                      3 - 5 lakh per annum
# 408  409  40-55                     5 - 10 lakh per annum
# 414  415    55+                        20+ lakh per annum
# ...

# %%
data_present.iloc[prev_current_smokers].describe(include='O')
# Out:
#           Age              Income         Emp_stat_Present Gender  \
# count      17                  16                       16     17
# unique      5                   5                        5      3
# top     20-25  20+ lakh per annum  Private Sector Employee   Male
# freq        5                   5                        9     15
#
#        Marital_status        Loc Notice_things_Present All_angles_Present  \
# count              17         17                    16                 16
# unique              2          7                     4                  3
# top               Yes  Telangana        Strongly agree              Agree
# freq               10         10                     7                  8
#
#        Sincere_prod_Present  Lonely_Present Worry_health_Present  \
# count                    17              17                   17
# unique                    4               5                    5
# ...

# %%
current_non_smokers = data_present[(data_present['Smoking_hab_Present']=='Former smoker') | 
            
            (data_present['Smoking_hab_Present']=='Never smoked')]['ID'].values

# %%
prev_smokers_current_nonsmokers = []

# %%
for i_D in prev_smokers:
    if i_D in current_non_smokers:
        prev_smokers_current_nonsmokers.append(i_D-1)

# %%
data_before.iloc[prev_smokers_current_nonsmokers]
# Out:
#       ID    Age                  Income          Emp_stat_Before  Gender  \
# 47    48  25-30      20+ lakh per annum  Private Sector Employee  Female
# 77    78  25-30   5 - 10 lakh per annum  Private Sector Employee    Male
# 84    85  25-30   5 - 10 lakh per annum            Self-Employed    Male
# 156  157  25-30    3 - 5 lakh per annum            Self-Employed    Male
# 172  173  20-25    3 - 5 lakh per annum  Private Sector Employee  Female
# 195  196  40-55      20+ lakh per annum  Private Sector Employee    Male
# 221  222  20-25    3 - 5 lakh per annum  Private Sector Employee    Male
# 237  238  25-30    3 - 5 lakh per annum  Private Sector Employee    Male
# 252  253  20-25    3 - 5 lakh per annum  Private Sector Employee    Male
# 353  354  20-25    3 - 5 lakh per annum  Private Sector Employee    Male
# 428  429    55+  10 - 20 lakh per annum  Private Sector Employee  Female
# 449  450  35-40  10 - 20 lakh per annum  Private Sector Employee    Male
# ...

# %%
data_present.iloc[prev_smokers_current_nonsmokers]
# Out:
#       ID    Age                  Income  \
# 47    48  25-30      20+ lakh per annum
# 77    78  25-30   5 - 10 lakh per annum
# 84    85  25-30   5 - 10 lakh per annum
# 156  157  25-30    3 - 5 lakh per annum
# 172  173  20-25    3 - 5 lakh per annum
# 195  196  40-55      20+ lakh per annum
# 221  222  20-25    3 - 5 lakh per annum
# 237  238  25-30    3 - 5 lakh per annum
# 252  253  20-25    3 - 5 lakh per annum
# 353  354  20-25    3 - 5 lakh per annum
# 428  429    55+  10 - 20 lakh per annum
# 449  450  35-40  10 - 20 lakh per annum
# 454  455  40-55      20+ lakh per annum
# 466  467  30-35  10 - 20 lakh per annum
# 467  468  30-35      20+ lakh per annum
# 477  478  25-30   5 - 10 lakh per annum
# 479  480  20-25  Under 3 lakh per annum
#
#                             Emp_stat_Present  Gender Marital_status  \
# 47                   Private Sector Employee  Female             No
# 77                   Private Sector Employee    Male             No
# ...

# %%
data_present.iloc[prev_smokers_current_nonsmokers].describe(include='O')
# Out:
#           Age                Income         Emp_stat_Present Gender  \
# count      17                    17                       16     17
# unique      6                     5                        3      2
# top     25-30  3 - 5 lakh per annum  Private Sector Employee   Male
# freq        6                     6                        9     13
#
#        Marital_status        Loc Notice_things_Present All_angles_Present  \
# count              17         16                    17                 16
# unique              2          8                     3                  3
# top                No  Telangana        Strongly agree              Agree
# freq               10          5                     9                  9
#
#        Sincere_prod_Present Lonely_Present Worry_health_Present  \
# count                    17             17                   17
# unique                    4              5                    4
# ...

# %%
'''
Above is a transition matrix that captures the shift in the smoking habits of people :-

NON-SMOKERS :-

1.393 out of 403 people who didnot have the habit of smoking before the pandemic are still continuing to maintain
the same,compared to the proportion of non-smokers the people who have shifted to smoking
are very less(7, almost negligible)

Even though negligible, If we dig a little bit deep and observe the charecteristics of these people :-
A.Majority of them,that is 67% of them are in the age group of 35-55 years, earning an average income of 15 lakh per 
annum, belonging to the states mostly north of India.Considering the proportion of the respective categories(age,
income,location) this is a significant observation.
B.80% of them agreed that they feel lonely in life currently and spend most of the day online,and also that
they worry about their health currently but are still not maintaining a healthy lifestyle.

SMOKERS :-

2.Now looking at the people who used to smoke before and are continuing to do so, we can say
that 50% of the people who used to smoke before are still continuing and following are their charecteristics:-

A.58% of these people are married and are between the age group 40-55 and 55+ and have the irregular sleeping 
habit of late to bed and early to rise and are also social drinkers.Considering the proportion of married people and
people in the age group of 40-55 and 55+ who have taken this survey ,we can say that
this a very significant observation.

3.Now coming to the crucial 50% of the people who actually chose to quit smoking, following are their 
charecteristics :-
A.Nearly 70% of these people are youth between 20-30 years of age and have a stable average income
of 7 lakh per annum and have also agreed on welcoming certain healthy changes in their lives,
like not only worrying about their health but also acting towards it and maintain a healthy lifestyle,nearly 42% of
these people agreed that they started being more productive at work and started thinking from different perspectives
before taking a decision which wasn't the case before.

'''

# %%
# Healthy_Lifestyle_Present - wrt to age groups,marital status,gender,Emp_stat_Present
# to verify thet there is a correlation between the two variables healthylifestyle,worryabout health
plt.figure(figsize=(15,7))
sns.countplot(data_present['Healthy_Lifestyle_Present'],hue='Worry_health_Present',data=data_present)
plt.show()

# %%
# to verify thet there is a correlation between the two variables healthylifestyle,worryabout health
plt.figure(figsize=(15,7))
sns.countplot(data_before['Healthy_Lifestyle_Before'],hue='Worry_health_Before',data=data_before)
plt.show()

# %%
(data_before['Age'].value_counts()/data_before['Age'].value_counts().sum())*100
# Out:
# 20-25      47.731397
# 25-30      15.607985
# 40-55      14.882033
# 30-35      10.344828
# 35-40       5.807623
# 55+         5.263158
# No Data     0.362976
# Name: Age, dtype: float64

# %%
# overall shift from non healthy lifestyle to healthy lifestyle
transition_matrix_healthy_lifestyle = pd.crosstab(index=data_before['Healthy_Lifestyle_Before'],
                                               columns=data_present['Healthy_Lifestyle_Present'],
                                               margins=True, margins_name="Total"
            )

# %%
transition_matrix_healthy_lifestyle1 = pd.crosstab(index=data_before['Healthy_Lifestyle_Before'],
                                               columns=data_present['Healthy_Lifestyle_Present'],
                                               normalize='index',margins=True, margins_name="Total"
            )*100

# %%
transition_matrix_healthy_lifestyle1
# Out:
# Healthy_Lifestyle_Present      Agree   Disagree    Neutral  Strongly Disagree  \
# Healthy_Lifestyle_Before
# Agree                      58.139535  12.790698  11.627907           0.000000
# Disagree                   21.428571  35.714286  32.142857           5.357143
# Neutral                    25.380711   4.060914  60.913706           2.030457
# No Data                    28.571429  14.285714  42.857143           0.000000
# Strongly Disagree           7.692308   7.692308  23.076923          53.846154
# Strongly agree             13.402062   2.061856  10.309278           2.061856
# Total                      32.841328   9.963100  32.103321           2.952030
#
# Healthy_Lifestyle_Present  Strongly agree
# Healthy_Lifestyle_Before
# Agree                           17.441860
# Disagree                         5.357143
# Neutral                          7.614213
# No Data                         14.285714
# Strongly Disagree                7.692308
# ...

# %%
17.441860+

# %%
transition_matrix_healthy_lifestyle
# Out:
# Healthy_Lifestyle_Present  Agree  Disagree  Neutral  Strongly Disagree  \
# Healthy_Lifestyle_Before
# Agree                        100        22       20                  0
# Disagree                      12        20       18                  3
# Neutral                       50         8      120                  4
# No Data                        2         1        3                  0
# Strongly Disagree              1         1        3                  7
# Strongly agree                13         2       10                  2
# Total                        178        54      174                 16
#
# Healthy_Lifestyle_Present  Strongly agree  Total
# Healthy_Lifestyle_Before
# Agree                                  30    172
# Disagree                                3     56
# Neutral                                15    197
# No Data                                 1      7
# Strongly Disagree                       1     13
# Strongly agree                         70     97
# ...

# %%
((178+120)/542)*100
# Out:
# 54.981549815498155

# %%
((172+97)/542)*100
# Out:
# 49.6309963099631

# %%
# people who worry about their health
transition_matrix_worry_health = pd.crosstab(index=data_before['Worry_health_Before'],
                                               columns=data_present['Worry_health_Present'],
                                               margins=True, margins_name="Total"
            )

# %%
((129+36)/542)*100
# Out:
# 30.44280442804428

# %%
(209+164)/542
# Out:
# 0.6881918819188192

# %%
transition_matrix_worry_health
# Out:
# Worry_health_Present  Agree  Disagree  Neutral  Strongly Agree  \
# Worry_health_Before
# Agree                    69         0        3              56
# Disagree                 41        38        7              19
# Neutral                  81         3       81              43
# No Data                   5         0        3               1
# Strongly Agree            0         0        2              34
# Strongly disagree        13         5        5              11
# Total                   209        46      101             164
#
# Worry_health_Present  Strongly disagree  Total
# Worry_health_Before
# Agree                                 1    129
# Disagree                              3    108
# Neutral                               0    208
# No Data                               0      9
# Strongly Agree                        0     36
# Strongly disagree                    18     52
# Total                                22    542

# %%
# section of people to analyse from the overall shift above (strongly agree before - 97, 
#strongly agree present - 120) we need to analyse the 23 people clearly who got added, probably they shifted from being neutral
#to healthy(50 people went from neutral to agreeing thet they have a healthy lifestyle), we need to analyse them

# %%
len(data_present[((data_present['Healthy_Lifestyle_Present'] == 'Disagree') | 
              (data_present['Healthy_Lifestyle_Present'] == 'Strongly Disagree')) &
            ((data_present['Worry_health_Present'] == 'Agree') | 
             (data_present['Worry_health_Present'] == 'Strongly Agree')) ])
# Out:
# 53

# %%
data_present[((data_present['Healthy_Lifestyle_Present'] == 'Disagree') | 
              (data_present['Healthy_Lifestyle_Present'] == 'Strongly Disagree')) &
            ((data_present['Worry_health_Present'] == 'Agree') | 
             (data_present['Worry_health_Present'] == 'Strongly Agree'))]
# Out:
#       ID    Age                                    Income  \
# 12    13  20-25                    10 - 20 lakh per annum
# 18    19  20-25                     5 - 10 lakh per annum
# 27    28  20-25  I don't earn right now (maybe in future)
# 40    41  30-35                      3 - 5 lakh per annum
# 45    46  20-25                     5 - 10 lakh per annum
# 52    53  20-25  I don't earn right now (maybe in future)
# 79    80  20-25                     5 - 10 lakh per annum
# 98    99  20-25                     5 - 10 lakh per annum
# 127  128    55+                     5 - 10 lakh per annum
# 136  137  25-30                    10 - 20 lakh per annum
# 150  151  25-30                      3 - 5 lakh per annum
# 173  174  25-30                      3 - 5 lakh per annum
# 174  175  20-25  I don't earn right now (maybe in future)
# 180  181  40-55  I don't earn right now (maybe in future)
# 207  208  20-25  I don't earn right now (maybe in future)
# ...

# %%
female_Ids = data_present[((data_present['Healthy_Lifestyle_Present'] == 'Disagree') | 
              (data_present['Healthy_Lifestyle_Present'] == 'Strongly Disagree')) &
            ((data_present['Worry_health_Present'] == 'Agree') | 
             (data_present['Worry_health_Present'] == 'Strongly Agree')) &
            (data_present['Age']=='20-25') & (data_present['Gender']=='Female')]['ID'].values

# %%
data_present[((data_present['Healthy_Lifestyle_Present'] == 'Disagree') | 
              (data_present['Healthy_Lifestyle_Present'] == 'Strongly Disagree')) &
            ((data_present['Worry_health_Present'] == 'Agree') | 
             (data_present['Worry_health_Present'] == 'Strongly Agree')) ].describe(include='O')
# Out:
#           Age                                    Income  \
# count      53                                        51
# unique      6                                         5
# top     20-25  I don't earn right now (maybe in future)
# freq       30                                        19
#
#                Emp_stat_Present  Gender Marital_status        Loc  \
# count                        44      53             53         52
# unique                        5       3              2         14
# top     Private Sector Employee  Female             No  Telangana
# freq                         16      30             34         23
#
#        Notice_things_Present All_angles_Present Sincere_prod_Present  \
# count                     53                 53                   53
# unique                     5                  3                    5
# top           Strongly agree     Strongly Agree                Agree
# freq                      23                 26                   26
#
# ...

# %%
data_present[((data_present['Healthy_Lifestyle_Present'] == 'Disagree') | 
              (data_present['Healthy_Lifestyle_Present'] == 'Strongly Disagree')) &
            ((data_present['Worry_health_Present'] == 'Agree') | 
             (data_present['Worry_health_Present'] == 'Strongly Agree')) &
            (data_present['Age']=='20-25') & (data_present['Gender']=='Female')].describe(include='O')
# Out:
#           Age                                    Income Emp_stat_Present  \
# count      21                                        19               18
# unique      1                                         3                4
# top     20-25  I don't earn right now (maybe in future)          Student
# freq       21                                        14                9
#
#         Gender Marital_status        Loc Notice_things_Present  \
# count       21             21         21                    21
# unique       1              2          7                     4
# top     Female             No  Telangana        Strongly agree
# freq        21             17         11                    10
#
#        All_angles_Present Sincere_prod_Present Lonely_Present  \
# count                  21                   21             21
# unique                  2                    4              5
# top        Strongly Agree                Agree          Agree
# ...

# %%
data_before.iloc[female_Ids].describe(include='O')
# Out:
#           Age                                    Income  \
# count      21                                        21
# unique      4                                         7
# top     20-25  I don't earn right now (maybe in future)
# freq       13                                         7
#
#                 Emp_stat_Before  Gender Marital_status        Loc  \
# count                        21      21             21         21
# unique                        6       3              2          7
# top     Private Sector Employee  Female             No  Telangana
# freq                          7      12             15         13
#
#        Notice_things_Before All_angles_Before Sincere_prod_Before  \
# count                    21                21                  21
# unique                    4                 4                   4
# top                   Agree           Neutral      Strongly agree
# freq                      7                 8                   9
#
# ...

# %%
ids_present_healthy = data_present[((data_present['Healthy_Lifestyle_Present'] == 'Agree') | 
              (data_present['Healthy_Lifestyle_Present'] == 'Strongly Agree'))]['ID'].values

# %%
len(ids_present_healthy)
# Out:
# 178

# %%
ids_healthy = data_before.iloc[ids_present_healthy][(data_before['Healthy_Lifestyle_Before']=='Disagree') |
                                      (data_before['Healthy_Lifestyle_Before']=='Strongly Disagree')]['ID'].values
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
data_before.iloc[ids_present_healthy][(data_before['Healthy_Lifestyle_Before']=='Disagree') |
                                      (data_before['Healthy_Lifestyle_Before']=='Strongly Disagree')].describe(include='O')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#           Age                                    Income  \
# count      23                                        23
# unique      5                                         6
# top     20-25  I don't earn right now (maybe in future)
# freq       13                                         8
#
#                 Emp_stat_Before  Gender Marital_status        Loc  \
# count                        23      23             23         23
# unique                        5       2              2         10
# top     Private Sector Employee  Female             No  Telangana
# freq                         11      16             14          9
#
#        Notice_things_Before All_angles_Before Sincere_prod_Before  \
# count                    23                23                  23
# ...

# %%
'''
From the above plots we can make the following observations :-

1.49.6% people used to have a healthy lifestyle before which now shifted to 55% 

2.30.4% of the people used to worry about their health which now shifted to 68.8% 

3.The huge shift in the people worrying about their health(almost double) and a very negligible shift in the people
maintaining a healthy lifestyle tells us an interesting story here:-
3.A These can be the people who are actually worried about their health but are not taking any action towards
doing something productive and maintaining a healthy routine.
3.B If we dig deep into people holding this behaviour, we can observe that they are dominated by unmarried femles
in the age group of 20-25,who are not earning currently, who spend most of the day online,and have an irregular
sleeping habits of late to bed and late to rise.They are worrying strongly about their health but still not taking
any action.
3.C Earlier, they were neutral about the health aspects of their lives , the pandemic did bring in a change of noticing
the importance of health for them, but not to that intensity that they actually start working towards it. Its again
proved here that end of the day its ones own determination that can bring in change, not the external situation.

4.Having said that,there is an appreciable lot that are actually worried and are taking action by maintaining
a healthy routine, these are the males between the age group 20-30 working with an average income of
7 lakh per annum , who had a neutral opinion on health aspects and had a habit of eating outside frequently,
which now changed to maintaing a healthy lifestyle , eating home cooked food and waking up early.

'''
